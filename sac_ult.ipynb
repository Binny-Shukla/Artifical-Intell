# %% [markdown]
# # The Ultimate SAC

# %% [markdown]
# # Import tools

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import gymnasium as gym
from gymnasium.wrappers import RescaleAction
import copy

import warnings

# %% [markdown]
# ## Preferences

# %%
warnings.filterwarnings('ignore' , category = UserWarning)

# %% [markdown]
# # Env Setup

# %%
env = gym.make('Humanoid-v5' , max_episode_steps = 3000)
env = RescaleAction(env , min_action = -1.0 , max_action = 1.0)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

action_max = env.action_space.high[0]

print(f'State dim : {state_dim} | Action dim : {action_dim} | Action max : {action_max}')
# Out:
# State dim : 348 | Action dim : 17 | Action max : 1.0

# %% [markdown]
# ## Device setup

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device : {device}')
# Out:
# Device : cuda

# %%
log_std_min = -10
log_std_max = 2

# %% [markdown]
# # ULtimate design

# %% [markdown]
# ### Feature extractor

# %%
class feature_extractor(nn.Module):
    def __init__(self, input_dim , output_dim , h):
        super(feature_extractor , self).__init__()
        
        
        self.f1 = nn.Sequential(
            
            nn.Linear(input_dim , h),
            nn.Linear(h,h),
        )
        
        
        self.gru = nn.GRU(input_size = h , hidden_size = h , num_layers = 1 ,batch_first = True)
        #self.gru_prod = nn.Linear(512 , h)
        self.multi = nn.MultiheadAttention(embed_dim = h , num_heads = 8 , batch_first = True)
        
        
        self.f = nn.Sequential(
            
            nn.Linear(h , h),
            nn.LayerNorm(h),
            nn.SiLU(),
            
            
            nn.Linear(h , h),
            nn.SiLU(),
            
            nn.Linear(h , h),
            nn.SiLU(),
            
            nn.Linear(h , h),
            nn.LayerNorm(h),
            nn.SiLU(),
            
            nn.Linear(h , h),
            nn.SiLU(),
            
            
            nn.Linear(h , output_dim),
            nn.SiLU(),
        )
        
        
        self.h = h
        
    def forward(self , x , hidden = None):
        
        if x.dim() == 1:
            x = x.unsqueeze(0)
        else:
            x = x.squeeze(1)
            
            
        x = self.f1(x)
        
        gru_out , hidden = self.gru(x , hidden)
        #gru_prod = self.gru_prod(gru_out)
        
        x = x.unsqueeze(1)
        adv , _ = self.multi(gru_out , gru_out , gru_out)
        adv = adv.reshape(-1 , self.h)
        adv = F.silu(adv)
        
        
        x1 = self.f(adv)
        
        return x1

# %% [markdown]
# ### Actor network

# %%
class actor(nn.Module):
    def __init__(self, state_dim , action_dim , head1 , head2 , head3 , head4 , h1 , feature_extractor = feature_extractor , max_action_range = action_max):
        super(actor , self).__init__()
        
        # Feature extractor
        self.feature = feature_extractor(state_dim , head1 , h1)
        
        # 4 Layers + SiLU
        self.fc = nn.Sequential(
            
            nn.Linear(head1 , head1),
            nn.LayerNorm(head1),
            nn.SiLU(),
            
            nn.Linear(head1 , head2),
            nn.SiLU(),
            
            nn.Linear(head2 , head3),
            nn.SiLU(),
            
            nn.Linear(head3 , head4),
            nn.LayerNorm(head4),
            nn.SiLU()
        )
        
        self.mu = nn.Linear(head4 , action_dim)
        
        self.log_std = nn.Linear(head4 , action_dim)
        
        self.max_action = max_action_range
        
    def forward(self , state):
        
        x = self.feature(state)
        
        x = self.fc(x)
        
        mu = self.mu(x)
        log_std = self.log_std(x)
        
        # Smoother scaling (key improvement)
        mu = torch.tanh(mu) * 0.5  # Constrain initial mu to [-0.5, 0.5]
        log_std = torch.tanh(log_std)  # Constrain log_std to [-1, 1] before scaling
        
        log_std = torch.clamp(log_std , log_std_min , log_std_max)
        std = torch.exp(log_std)
        
        # Reparamaterization trick
        
        normal = torch.distributions.Normal(mu , std)
        z = normal.rsample()
        tanh_z = torch.tanh(z)
        action = tanh_z * self.max_action
        
        
        # Tanh Squashing
        
        log_prob = normal.log_prob(z)
        squash = 2 * (torch.log(torch.tensor(2.0, device=z.device)) - z - F.softplus(-2 * z))
        log_prob = log_prob - squash
        log_prob = log_prob.sum(dim = 1 , keepdim = True)
        
        return action , log_prob

# %% [markdown]
# ### Critic network

# %%
class critic(nn.Module):
    def __init__(self, state_dim , action_dim , head1 , head2 , head3 , head4 , h1 , feature_extractor = feature_extractor):
        super(critic , self).__init__()
        
        # Feature
        self.feature = feature_extractor(state_dim + action_dim , head1 , h1)
        
        # 2 Critic - c1 & c2
        self.c1 = nn.Sequential(
            
            nn.Linear(head1 , head1),
            nn.LayerNorm(head1),
            nn.SiLU(),
            
            nn.Linear(head1 , head2),
            nn.SiLU(),
            
            nn.Linear(head2 , head3),
            nn.SiLU(),
            
            nn.Linear(head3 , head4),
            nn.LayerNorm(head4),
            nn.SiLU(),
            
            nn.Linear(head4 , 1)
        )
        
        
        self.c2 = nn.Sequential(
            
            nn.Linear(head1 , head1),
            nn.LayerNorm(head1),
            nn.SiLU(),
            
            nn.Linear(head1 , head2),
            nn.SiLU(),
            
            nn.Linear(head2 , head3),
            nn.SiLU(),
            
            nn.Linear(head3 , head4),
            nn.LayerNorm(head4),
            nn.SiLU(),
            
            nn.Linear(head4 , 1)
        )
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=0.01)
                nn.init.constant_(m.bias, 0.0)
        
    def forward(self , state , action):
                
        if state.dim() == 3:
            state = state.squeeze(1)
        if action.dim() == 3:
            action = action.squeeze(1)

        
        sa = torch.cat([state , action] , dim = 1)
        feature = self.feature(sa)
        feature = feature + 0.1 * feature.detach()
        
        q1 = self.c1(feature)
        q2 = self.c2(feature)
        
        return q1 , q2

# %% [markdown]
# ## Model Setup

# %%
# Neuron setting
head1 = 256
head2 = 512
head3 = 512
head4 = 256
h1 = 256

# Model

actor_network = actor(state_dim , action_dim , head1 , head2 , head3 , head4 , h1).to(device)
critic_network = critic(state_dim , action_dim , head1 , head2 , head3 , head4 , h1).to(device)

target_critic = copy.deepcopy(critic_network).to(device)

print('-----------------------------------------------------------------------')
print(actor_network)
print('-----------------------------------------------------------------------')
print(critic_network)
# Out:
# -----------------------------------------------------------------------
# actor(
#   (feature): feature_extractor(
#     (f1): Sequential(
#       (0): Linear(in_features=348, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (gru): GRU(256, 256, batch_first=True)
#     (multi): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#     )
#     (f): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SiLU()
#       (5): Linear(in_features=256, out_features=256, bias=True)
#       (6): SiLU()
#       (7): Linear(in_features=256, out_features=256, bias=True)
#       (8): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (9): SiLU()
#       (10): Linear(in_features=256, out_features=256, bias=True)
#       (11): SiLU()
#       (12): Linear(in_features=256, out_features=256, bias=True)
#       (13): SiLU()
#     )
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): SiLU()
#     (3): Linear(in_features=256, out_features=512, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): SiLU()
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (9): SiLU()
#   )
#   (mu): Linear(in_features=256, out_features=17, bias=True)
#   (log_std): Linear(in_features=256, out_features=17, bias=True)
# )
# -----------------------------------------------------------------------
# critic(
#   (feature): feature_extractor(
#     (f1): Sequential(
#       (0): Linear(in_features=365, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (gru): GRU(256, 256, batch_first=True)
#     (multi): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#     )
#     (f): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SiLU()
#       (5): Linear(in_features=256, out_features=256, bias=True)
#       (6): SiLU()
#       (7): Linear(in_features=256, out_features=256, bias=True)
#       (8): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (9): SiLU()
#       (10): Linear(in_features=256, out_features=256, bias=True)
#       (11): SiLU()
#       (12): Linear(in_features=256, out_features=256, bias=True)
#       (13): SiLU()
#     )
#   )
#   (c1): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): SiLU()
#     (3): Linear(in_features=256, out_features=512, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): SiLU()
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (9): SiLU()
#     (10): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (c2): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): SiLU()
#     (3): Linear(in_features=256, out_features=512, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): SiLU()
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (9): SiLU()
#     (10): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # PER As Roller Buffer

# %%
class PER_new():
    def __init__(self, capacity, batch_size, beta=0.4, alpha_per=0.6):
        self.capacity = capacity
        self.buffer = []
        self.priorities = np.zeros(capacity, dtype=np.float32)
        self.avg_priority = 1.0
        self.beta = beta
        self.alpha_per = alpha_per
        self.batch_size = batch_size

    def add(self, state, action, reward, next_state, done):
        
        # convert them to tensor
        state = state
        next_state = next_state
        reward = torch.tensor(reward , dtype = torch.float32).to(device)
        action = torch.tensor(action ,dtype = torch.float32).to(device)
        done = torch.tensor(done , dtype = torch.float32).to(device)
        
        max_priority = self.priorities.max() if self.buffer else 1.0
        
        if len(self.buffer) < self.capacity:
            self.buffer.append((state, action, reward, next_state, done))
            self.priorities[len(self.buffer)-1] = max_priority
        else:
            idx = np.argmin(self.priorities)
            self.buffer[idx] = (state, action, reward, next_state, done)
            self.priorities[idx] = max_priority

    def sample(self):
        if len(self.buffer) == 0:
            raise ValueError("Buffer is empty")
            
        probs = self.priorities[:len(self.buffer)] ** self.alpha_per
        probs /= probs.sum()
        
        indices = np.random.choice(len(self.buffer), size=min(self.batch_size, len(self.buffer)), 
                                 p=probs, replace=False)
        samples = [self.buffer[i] for i in indices]
        
        weights = (len(self.buffer) * probs[indices]) ** -self.beta
        weights /= weights.max()
        
        return samples, indices, torch.FloatTensor(weights).to(device)

    def update_priorities(self, indices, td_errors):
        # Ensure td_errors is numpy array with correct shape
        if isinstance(td_errors, torch.Tensor):
            td_errors = td_errors.detach().cpu().numpy()
        td_errors = np.reshape(td_errors, -1)  # Flatten
        
        # Clip and update
        clipped_errors = np.clip(td_errors, -6, 10)
        self.priorities[indices] = np.abs(clipped_errors) + 1e-6
        self.avg_priority = 0.99 * self.avg_priority + 0.01 * np.mean(clipped_errors)

# %% [markdown]
# ### Replay buffer setup

# %%
# Buffer hyper params
capacity = 500_000
batch_size = 512

# Buffer setup
buffer = PER_new(capacity , batch_size)

# %% [markdown]
# # Soft update

# %%
def soft_update(target , source , tau = 0.0067):
    
    for target_param , param in zip(target.parameters() , source.parameters()):
        
        target_param.data.copy_((tau * param.data) + ((1 - tau) * target_param.data))

# %% [markdown]
# # Loss function

# %%
class loss_function():
    def __init__(self , gamma , action_dim , actor_network , critic_network , target_critic , policy_delay , total_step , critic_optimizer , critic_scheduler , actor_optimizer , actor_scheduler , soft_update , batch_size , episode):
        
        self.actor = actor_network
        self.critic = critic_network
        self.target_critic = target_critic
        self.gamma = gamma
        self.action_dim = action_dim
        self.critic_optimizer = critic_optimizer
        self.critic_scheduler = critic_scheduler
        self.actor_optimizer = actor_optimizer
        self.actor_scheduler = actor_scheduler
        self.total_step = total_step
        self.policy_delay = policy_delay
        self.update = soft_update
        self.batch_size = batch_size
        self.episode = episode
        
        # Entropy
        
        def update_entropy(episode):
            
            if episode < 3000 :
                self.target_entropy = - self.action_dim * 1.5
            elif 3000 < episode < 7000 :
                self.target_entropy = - self.action_dim * 1.0
            else:
                self.target_entropy = - self.action_dim * 0.8 
                  
            return self.target_entropy
        
        
        self.log_alpha = torch.tensor(np.log(0.2) , requires_grad = True , device = device)
        self.alpha_optimizer = optim.AdamW([self.log_alpha] , lr = 1e-4 , weight_decay = 0.01)
        self.target_entropy = update_entropy(episode)
        self.alpha_min = 0.15
        
        
    def compute_loss(self , state , action , reward , next_state , done , weights):
        
        # Alpha 
        
        self.alpha = self.log_alpha.exp().detach()
        self.alpha = self.alpha.clamp(min = self.alpha_min)
        
        # Tesnor handling
        
        state = torch.stack(state).to(device)
        action = torch.stack(action).to(device)
        reward = torch.stack(reward).unsqueeze(1).to(device)
        next_state = torch.stack(next_state).to(device)
        done = torch.stack(done).unsqueeze(1).to(device)
        weights = torch.tensor(weights , dtype = torch.float32).unsqueeze(1).to(device)
        
        # Compute target_value
        
        with torch.no_grad():
            next_actions , next_log_probs = self.actor(next_state)
            if next_actions.dim() == 1:
                next_actions = next_actions.unsqueeze(0)

            target_1 , target_2 = self.target_critic(next_state , next_actions)
            target_q = (0.75 * torch.min(target_1, target_2) + 0.25 * torch.max(target_1, target_2)).clamp(-200 , 600) - self.alpha * next_log_probs          # Removed clamp from torch.min let them unbound
            target_vals = reward + self.gamma * (1 - done) * target_q
            
            
        # Current q val and critic loss
        
        current_q1 , current_q2 = self.critic(state , action)
        td_error_1 = F.huber_loss(current_q1 , target_vals , reduction = 'none')
        td_error2 = F.huber_loss(current_q2 , target_vals , reduction = 'none')
        
        critic_loss = (td_error2 + td_error_1) * weights
        critic_loss = critic_loss.mean()
        
        # Td error
        
        with torch.no_grad():
            td_error  = ((current_q1 - target_vals).abs() + (current_q2 - target_vals).abs()) / 2.0
            td_error = td_error.view(self.batch_size, -1).mean(1)
            
            
        # Optimize
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters() , max_norm = 0.5)
        self.critic_optimizer.step()
        
        
        # Actor loss
        
        new_action , log_prob = self.actor(state)
        with torch.no_grad():
            _ , old_log_prob = self.actor(state)              # replaced _ , old _log_prob with new_action and log_prob
            q1 , q2 = self.critic(state , new_action)
            q1 = q1.detach()
            q2 = q2.detach()
            q_pi = torch.min(q1 , q2)
            adv = q_pi - q_pi.mean()
        
        # Dummy actor loss
        
        kl_div = (log_prob - old_log_prob).mean()
        actor_loss = torch.tensor(0.0).to(device)
        
        # Optimize & Alpha loss
        if self.episode % self.policy_delay == 0 :  
            
            # Actor optimized
            actor_loss = (self.alpha * log_prob - adv).mean()
            actor_loss += 0.05 * kl_div
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.actor.parameters() , max_norm = 0.5)
            self.actor_optimizer.step()
                    
            # Soft update
            self.update(self.target_critic , self.critic)
            

        # alpha optimized
        log_prob = log_prob.detach()
        alpha_loss = -(self.log_alpha * (log_prob + self.target_entropy + 0.2 * kl_div.detach())).mean()
        self.alpha_optimizer.zero_grad()
        alpha_loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_([self.log_alpha], max_norm=float('inf'))
        if grad_norm > 10.0:  # Only clip if exploding
            torch.nn.utils.clip_grad_norm_([self.log_alpha], max_norm=10.0)
        torch.nn.utils.clip_grad_norm_([self.log_alpha] , max_norm = 1.0)           # Removed gradient clipping let it explode 
        self.alpha_optimizer.step()
            
        if self.episode % 1000 == 0:
            
            self.actor_scheduler.step(actor_loss.item())
            self.critic_scheduler.step(critic_loss.item())
            #self.target_entropy *= 0.99
            
            
        return actor_loss.item() , critic_loss.item() , self.alpha.item() , td_error

# %% [markdown]
# # Loss setup

# %%
# Hyper params
gamma = 0.999
policy_delay = 3
total_step = 0
episode = 0
actor_lr = 3e-5
critic_lr = 3e-4
max_iter = 5_000_000
n_steps = 1024

# Optimizers

actor_optimizer = optim.SGD(actor_network.parameters() , lr = actor_lr , weight_decay = 0.001 , momentum = 0.9 , nesterov = True)
critic_optimizer = optim.SGD(critic_network.parameters() , lr = critic_lr , weight_decay = 0.001 , momentum = 0.9 , nesterov = True)


# Schedulers

actor_scheduler = optim.lr_scheduler.CosineAnnealingLR(actor_optimizer , T_max = max_iter)
critic_scheduler = optim.lr_scheduler.CosineAnnealingLR(critic_optimizer , T_max = max_iter)

# loss setup

loss = loss_function(gamma = gamma , action_dim = action_dim ,actor_network = actor_network, critic_network = critic_network
                     ,target_critic = target_critic , policy_delay = policy_delay , total_step = total_step
                     ,critic_optimizer = critic_optimizer ,  critic_scheduler = critic_scheduler,
                     actor_optimizer = actor_optimizer , actor_scheduler = actor_scheduler,
                     soft_update = soft_update , batch_size = batch_size , episode = episode)

# %% [markdown]
# # Reward Shaping

# %%
def shaped_reward(reward , state , max_reward):
    
    is_falling = (state[2] < 0.8 or          # Height threshold
                 abs(state[3]) > 0.4 or      # Angular velocity X
                 abs(state[4]) > 0.4)        # Angular velocity Y
    
    if is_falling:
        
        recovery_bonus = 3.0 * (1 - abs(state[3]))
        survival_bonus = 0.5 * (0.8 - state[2])
        reward += recovery_bonus + survival_bonus
    
    else:
        
        reward += 0.05
        reward += 1.5 * state[1]
        reward += 0.3 * state[2] ** 2 # Height bonus quadritic
        reward += 1.5 * state[0] * (1 + state[2])   # Forward locomotion
        reward -= 0.1 * np.square(state[3:6]).sum()  # Angular penalty
        reward -= 0.1 * (state[3] ** 2 + state[4] ** 2)
        
    return reward / 10.0

# %%
def shaped_reward_2(reward, state , step):
    
    # Dynamic components
    progress = min(step / 500_000 , 1.0)
    target_speed = min(1.0 + 0.5 * progress , 2.0)
    forward_vel = state[0]
    height = state[2]
    
    # Progressive falling detection
    fall_risk = max(0, 0.8 - height) + 0.5*(abs(state[3]) + abs(state[4]))
    is_falling = fall_risk > 1.0
    
    # Episode length normalization
    #ep_length_factor = min(1.0, current_step/500)
    
    if is_falling:
        
        reward -= 1.0 * fall_risk  # Gradual penalty
        survival_bonus = 0.5 * (0.8 - state[2])   
        recovery_bonus = 3.0 * (1 - abs(state[3]))
        reward += survival_bonus + recovery_bonus
    else:
        
        # Speed reward (bell curve around target speed)
        speed_reward = 3.0 * np.clip(1 - abs(forward_vel - target_speed)/target_speed, 0, 1) * min(1.5, 1 + height)

        # Core rewards
        reward += 0.05  # Survival
        reward += 0.3 * height**2  # Upright
        reward += speed_reward  # Movement
        reward -= 0.3 * abs(state[1])  # Drift
        reward -= 0.1 * np.square(state[3:6]).sum()  # Angular penalty
        
        # Energy efficiency (if actions available)
        #if action is not None:
            #reward -= 0.01 * np.sum(np.square(action))
        
        # Foot contact bonus (if available)
        #if foot_contacts and all(foot_contacts):
            #reward += 0.2
    
    return reward

# %% [markdown]
# # Trainig Loop

# %%
n_steps = 1024
max_iter = 5_000_000
rewards_per_iter = []
ep_reward = 0
episode = 0
alpha = 0
total_env_steps = 0
max_reward = 10.0


state, _ = env.reset()

for iter in range(0, max_iter, n_steps):  # total steps = ~5M, chunked by 1024 steps

    for _ in range(n_steps):
        
        # Convert state to tensor
        if len(state.shape) == 1:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32).to(device)

        # Get action from actor
        action, _ = actor_network(state_tensor)
        action = action.squeeze(0).detach().cpu().numpy()

        # Step environment
        next_state, reward, done, _, _ = env.step(action)

        # Reward shaping
        reward = shaped_reward(reward = reward , state = state , max_reward = max_reward )#, step = total_env_steps)
        scaled_reward = reward 

        # Next state tensor
        if len(next_state.shape) == 1:
            next_state_tensor = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)
        else:
            next_state_tensor = torch.tensor(next_state, dtype=torch.float32).to(device)

        # Add to buffer
        buffer.add(state_tensor, action, scaled_reward, next_state_tensor, done)
        
        # Increment
        
        state = next_state
        ep_reward += scaled_reward
        total_env_steps += 1 
        loss.total_step = total_env_steps

        if done:
            rewards_per_iter.append(ep_reward)
            if ep_reward > max_reward:
                max_reward = ep_reward
            print(f"Alpha: {alpha:.4f} | Episode: {loss.episode} | Step: {total_env_steps} | Reward: {ep_reward:.2f} | Max : {max_reward:.2f}")
            ep_reward = 0
            loss.episode += 1
            state, _ = env.reset()

    # Only update after n_steps
    if len(buffer.buffer) > 10_000:
        batch, indices, weights = buffer.sample()
        states, actions, rewards, next_states, dones = zip(*batch)

        actor_loss, critic_loss, alpha, td_error = loss.compute_loss(
            states, actions, rewards, next_states, dones, weights
        )
        buffer.update_priorities(indices , td_error.detach().cpu().numpy())

        
    # Optional: save model every X steps
    if iter % 50_000 == 0:
        torch.save(actor_network.state_dict(), f"sac_actor_step_{iter}.pth")
        torch.save(critic_network.state_dict(), f"sac_critic_step_{iter}.pth")

# Final save
torch.save(actor_network.state_dict(), "sac_actor_final.pth")
torch.save(critic_network.state_dict(), "sac_critic_final.pth")
# Out:
# Alpha: 0.0000 | Episode: 0 | Step: 22 | Reward: 16.87 | Max : 16.87
# Alpha: 0.0000 | Episode: 1 | Step: 62 | Reward: 31.23 | Max : 31.23
# Alpha: 0.0000 | Episode: 2 | Step: 81 | Reward: 14.91 | Max : 31.23
# Alpha: 0.0000 | Episode: 3 | Step: 98 | Reward: 13.39 | Max : 31.23
# Alpha: 0.0000 | Episode: 4 | Step: 126 | Reward: 22.14 | Max : 31.23
# Alpha: 0.0000 | Episode: 5 | Step: 148 | Reward: 17.52 | Max : 31.23
# Alpha: 0.0000 | Episode: 6 | Step: 166 | Reward: 14.26 | Max : 31.23
# Alpha: 0.0000 | Episode: 7 | Step: 188 | Reward: 17.36 | Max : 31.23
# Alpha: 0.0000 | Episode: 8 | Step: 224 | Reward: 26.76 | Max : 31.23
# Alpha: 0.0000 | Episode: 9 | Step: 241 | Reward: 13.09 | Max : 31.23
# Alpha: 0.0000 | Episode: 10 | Step: 278 | Reward: 26.94 | Max : 31.23
# Alpha: 0.0000 | Episode: 11 | Step: 295 | Reward: 13.05 | Max : 31.23
# Alpha: 0.0000 | Episode: 12 | Step: 312 | Reward: 13.53 | Max : 31.23
# Alpha: 0.0000 | Episode: 13 | Step: 335 | Reward: 17.66 | Max : 31.23
# Alpha: 0.0000 | Episode: 14 | Step: 352 | Reward: 13.26 | Max : 31.23
# Alpha: 0.0000 | Episode: 15 | Step: 388 | Reward: 25.60 | Max : 31.23
# Alpha: 0.0000 | Episode: 16 | Step: 409 | Reward: 16.60 | Max : 31.23
# Alpha: 0.0000 | Episode: 17 | Step: 446 | Reward: 26.84 | Max : 31.23
# Alpha: 0.0000 | Episode: 18 | Step: 468 | Reward: 17.61 | Max : 31.23
# Alpha: 0.0000 | Episode: 19 | Step: 489 | Reward: 16.74 | Max : 31.23
# Alpha: 0.0000 | Episode: 20 | Step: 514 | Reward: 18.85 | Max : 31.23
# Alpha: 0.0000 | Episode: 21 | Step: 536 | Reward: 17.61 | Max : 31.23
# Alpha: 0.0000 | Episode: 22 | Step: 568 | Reward: 24.55 | Max : 31.23
# Alpha: 0.0000 | Episode: 23 | Step: 602 | Reward: 25.57 | Max : 31.23
# Alpha: 0.0000 | Episode: 24 | Step: 622 | Reward: 15.75 | Max : 31.23
# Alpha: 0.0000 | Episode: 25 | Step: 642 | Reward: 16.01 | Max : 31.23
# Alpha: 0.0000 | Episode: 26 | Step: 668 | Reward: 18.90 | Max : 31.23
# Alpha: 0.0000 | Episode: 27 | Step: 706 | Reward: 28.74 | Max : 31.23
# Alpha: 0.0000 | Episode: 28 | Step: 726 | Reward: 15.99 | Max : 31.23
# Alpha: 0.0000 | Episode: 29 | Step: 756 | Reward: 22.99 | Max : 31.23
# Alpha: 0.0000 | Episode: 30 | Step: 782 | Reward: 20.09 | Max : 31.23
# Alpha: 0.0000 | Episode: 31 | Step: 799 | Reward: 13.22 | Max : 31.23
# Alpha: 0.0000 | Episode: 32 | Step: 817 | Reward: 14.30 | Max : 31.23
# Alpha: 0.0000 | Episode: 33 | Step: 834 | Reward: 13.29 | Max : 31.23
# Alpha: 0.0000 | Episode: 34 | Step: 860 | Reward: 20.25 | Max : 31.23
# Alpha: 0.0000 | Episode: 35 | Step: 877 | Reward: 13.36 | Max : 31.23
# Alpha: 0.0000 | Episode: 36 | Step: 896 | Reward: 14.68 | Max : 31.23
# Alpha: 0.0000 | Episode: 37 | Step: 920 | Reward: 18.51 | Max : 31.23
# Alpha: 0.0000 | Episode: 38 | Step: 943 | Reward: 17.35 | Max : 31.23
# Alpha: 0.0000 | Episode: 39 | Step: 962 | Reward: 14.32 | Max : 31.23
# Alpha: 0.0000 | Episode: 40 | Step: 1000 | Reward: 29.37 | Max : 31.23
# Alpha: 0.0000 | Episode: 41 | Step: 1020 | Reward: 15.78 | Max : 31.23
# Alpha: 0.0000 | Episode: 42 | Step: 1038 | Reward: 14.06 | Max : 31.23
# Alpha: 0.0000 | Episode: 43 | Step: 1058 | Reward: 15.90 | Max : 31.23
# Alpha: 0.0000 | Episode: 44 | Step: 1088 | Reward: 23.81 | Max : 31.23
# Alpha: 0.0000 | Episode: 45 | Step: 1104 | Reward: 12.28 | Max : 31.23
# Alpha: 0.0000 | Episode: 46 | Step: 1121 | Reward: 13.39 | Max : 31.23
# Alpha: 0.0000 | Episode: 47 | Step: 1138 | Reward: 13.18 | Max : 31.23
# Alpha: 0.0000 | Episode: 48 | Step: 1164 | Reward: 20.32 | Max : 31.23
# Alpha: 0.0000 | Episode: 49 | Step: 1184 | Reward: 15.78 | Max : 31.23
# Alpha: 0.0000 | Episode: 50 | Step: 1212 | Reward: 22.38 | Max : 31.23
# Alpha: 0.0000 | Episode: 51 | Step: 1244 | Reward: 24.39 | Max : 31.23
# Alpha: 0.0000 | Episode: 52 | Step: 1266 | Reward: 17.44 | Max : 31.23
# Alpha: 0.0000 | Episode: 53 | Step: 1283 | Reward: 13.34 | Max : 31.23
# Alpha: 0.0000 | Episode: 54 | Step: 1307 | Reward: 19.12 | Max : 31.23
# Alpha: 0.0000 | Episode: 55 | Step: 1325 | Reward: 14.29 | Max : 31.23
# Alpha: 0.0000 | Episode: 56 | Step: 1342 | Reward: 13.39 | Max : 31.23
# Alpha: 0.0000 | Episode: 57 | Step: 1362 | Reward: 15.70 | Max : 31.23
# Alpha: 0.0000 | Episode: 58 | Step: 1386 | Reward: 18.45 | Max : 31.23
# Alpha: 0.0000 | Episode: 59 | Step: 1429 | Reward: 33.17 | Max : 33.17
# Alpha: 0.0000 | Episode: 60 | Step: 1450 | Reward: 16.77 | Max : 33.17
# Alpha: 0.0000 | Episode: 61 | Step: 1469 | Reward: 14.91 | Max : 33.17
# Alpha: 0.0000 | Episode: 62 | Step: 1489 | Reward: 15.59 | Max : 33.17
# Alpha: 0.0000 | Episode: 63 | Step: 1510 | Reward: 15.64 | Max : 33.17
# Alpha: 0.0000 | Episode: 64 | Step: 1535 | Reward: 19.44 | Max : 33.17
# Alpha: 0.0000 | Episode: 65 | Step: 1551 | Reward: 12.55 | Max : 33.17
# Alpha: 0.0000 | Episode: 66 | Step: 1574 | Reward: 18.28 | Max : 33.17
# Alpha: 0.0000 | Episode: 67 | Step: 1590 | Reward: 12.56 | Max : 33.17
# Alpha: 0.0000 | Episode: 68 | Step: 1610 | Reward: 15.42 | Max : 33.17
# Alpha: 0.0000 | Episode: 69 | Step: 1639 | Reward: 20.71 | Max : 33.17
# Alpha: 0.0000 | Episode: 70 | Step: 1669 | Reward: 23.80 | Max : 33.17
# Alpha: 0.0000 | Episode: 71 | Step: 1686 | Reward: 13.06 | Max : 33.17
# Alpha: 0.0000 | Episode: 72 | Step: 1703 | Reward: 13.38 | Max : 33.17
# Alpha: 0.0000 | Episode: 73 | Step: 1721 | Reward: 14.38 | Max : 33.17
# Alpha: 0.0000 | Episode: 74 | Step: 1755 | Reward: 26.76 | Max : 33.17
# Alpha: 0.0000 | Episode: 75 | Step: 1773 | Reward: 14.08 | Max : 33.17
# Alpha: 0.0000 | Episode: 76 | Step: 1806 | Reward: 25.29 | Max : 33.17
# Alpha: 0.0000 | Episode: 77 | Step: 1839 | Reward: 26.38 | Max : 33.17
# Alpha: 0.0000 | Episode: 78 | Step: 1866 | Reward: 21.06 | Max : 33.17
# Alpha: 0.0000 | Episode: 79 | Step: 1884 | Reward: 14.32 | Max : 33.17
# Alpha: 0.0000 | Episode: 80 | Step: 1901 | Reward: 12.99 | Max : 33.17
# Alpha: 0.0000 | Episode: 81 | Step: 1931 | Reward: 23.45 | Max : 33.17
# Alpha: 0.0000 | Episode: 82 | Step: 1960 | Reward: 22.64 | Max : 33.17
# Alpha: 0.0000 | Episode: 83 | Step: 1982 | Reward: 17.46 | Max : 33.17
# Alpha: 0.0000 | Episode: 84 | Step: 2001 | Reward: 14.90 | Max : 33.17
# Alpha: 0.0000 | Episode: 85 | Step: 2017 | Reward: 12.36 | Max : 33.17
# Alpha: 0.0000 | Episode: 86 | Step: 2036 | Reward: 15.11 | Max : 33.17
# Alpha: 0.0000 | Episode: 87 | Step: 2061 | Reward: 20.00 | Max : 33.17
# Alpha: 0.0000 | Episode: 88 | Step: 2078 | Reward: 13.38 | Max : 33.17
# Alpha: 0.0000 | Episode: 89 | Step: 2101 | Reward: 18.05 | Max : 33.17
# Alpha: 0.0000 | Episode: 90 | Step: 2121 | Reward: 15.81 | Max : 33.17
# Alpha: 0.0000 | Episode: 91 | Step: 2139 | Reward: 14.10 | Max : 33.17
# Alpha: 0.0000 | Episode: 92 | Step: 2157 | Reward: 14.21 | Max : 33.17
# Alpha: 0.0000 | Episode: 93 | Step: 2176 | Reward: 15.19 | Max : 33.17
# Alpha: 0.0000 | Episode: 94 | Step: 2192 | Reward: 12.56 | Max : 33.17
# Alpha: 0.0000 | Episode: 95 | Step: 2216 | Reward: 19.13 | Max : 33.17
# Alpha: 0.0000 | Episode: 96 | Step: 2242 | Reward: 20.22 | Max : 33.17
# Alpha: 0.0000 | Episode: 97 | Step: 2260 | Reward: 14.00 | Max : 33.17
# Alpha: 0.0000 | Episode: 98 | Step: 2296 | Reward: 29.41 | Max : 33.17
# Alpha: 0.0000 | Episode: 99 | Step: 2321 | Reward: 19.15 | Max : 33.17
# Alpha: 0.0000 | Episode: 100 | Step: 2339 | Reward: 13.93 | Max : 33.17
# Alpha: 0.0000 | Episode: 101 | Step: 2357 | Reward: 14.33 | Max : 33.17
# Alpha: 0.0000 | Episode: 102 | Step: 2394 | Reward: 28.04 | Max : 33.17
# Alpha: 0.0000 | Episode: 103 | Step: 2411 | Reward: 13.34 | Max : 33.17
# Alpha: 0.0000 | Episode: 104 | Step: 2433 | Reward: 17.04 | Max : 33.17
# Alpha: 0.0000 | Episode: 105 | Step: 2473 | Reward: 31.38 | Max : 33.17
# Alpha: 0.0000 | Episode: 106 | Step: 2500 | Reward: 21.46 | Max : 33.17
# Alpha: 0.0000 | Episode: 107 | Step: 2516 | Reward: 12.49 | Max : 33.17
# Alpha: 0.0000 | Episode: 108 | Step: 2541 | Reward: 19.70 | Max : 33.17
# Alpha: 0.0000 | Episode: 109 | Step: 2573 | Reward: 23.80 | Max : 33.17
# Alpha: 0.0000 | Episode: 110 | Step: 2593 | Reward: 15.80 | Max : 33.17
# Alpha: 0.0000 | Episode: 111 | Step: 2612 | Reward: 14.58 | Max : 33.17
# Alpha: 0.0000 | Episode: 112 | Step: 2631 | Reward: 14.68 | Max : 33.17
# Alpha: 0.0000 | Episode: 113 | Step: 2653 | Reward: 17.49 | Max : 33.17
# Alpha: 0.0000 | Episode: 114 | Step: 2672 | Reward: 15.22 | Max : 33.17
# Alpha: 0.0000 | Episode: 115 | Step: 2692 | Reward: 15.46 | Max : 33.17
# Alpha: 0.0000 | Episode: 116 | Step: 2719 | Reward: 21.52 | Max : 33.17
# Alpha: 0.0000 | Episode: 117 | Step: 2743 | Reward: 18.74 | Max : 33.17
# Alpha: 0.0000 | Episode: 118 | Step: 2771 | Reward: 21.34 | Max : 33.17
# Alpha: 0.0000 | Episode: 119 | Step: 2788 | Reward: 13.31 | Max : 33.17
# Alpha: 0.0000 | Episode: 120 | Step: 2816 | Reward: 22.14 | Max : 33.17
# Alpha: 0.0000 | Episode: 121 | Step: 2838 | Reward: 17.26 | Max : 33.17
# Alpha: 0.0000 | Episode: 122 | Step: 2877 | Reward: 30.67 | Max : 33.17
# Alpha: 0.0000 | Episode: 123 | Step: 2900 | Reward: 18.15 | Max : 33.17
# Alpha: 0.0000 | Episode: 124 | Step: 2917 | Reward: 13.49 | Max : 33.17
# Alpha: 0.0000 | Episode: 125 | Step: 2935 | Reward: 14.30 | Max : 33.17
# Alpha: 0.0000 | Episode: 126 | Step: 2952 | Reward: 13.23 | Max : 33.17
# Alpha: 0.0000 | Episode: 127 | Step: 2976 | Reward: 18.26 | Max : 33.17
# Alpha: 0.0000 | Episode: 128 | Step: 2994 | Reward: 14.14 | Max : 33.17
# Alpha: 0.0000 | Episode: 129 | Step: 3020 | Reward: 20.09 | Max : 33.17
# Alpha: 0.0000 | Episode: 130 | Step: 3039 | Reward: 14.70 | Max : 33.17
# Alpha: 0.0000 | Episode: 131 | Step: 3060 | Reward: 17.01 | Max : 33.17
# Alpha: 0.0000 | Episode: 132 | Step: 3110 | Reward: 39.48 | Max : 39.48
# Alpha: 0.0000 | Episode: 133 | Step: 3127 | Reward: 13.20 | Max : 39.48
# Alpha: 0.0000 | Episode: 134 | Step: 3143 | Reward: 12.65 | Max : 39.48
# Alpha: 0.0000 | Episode: 135 | Step: 3166 | Reward: 17.94 | Max : 39.48
# Alpha: 0.0000 | Episode: 136 | Step: 3183 | Reward: 13.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 137 | Step: 3205 | Reward: 17.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 138 | Step: 3222 | Reward: 12.97 | Max : 39.48
# Alpha: 0.0000 | Episode: 139 | Step: 3260 | Reward: 28.97 | Max : 39.48
# Alpha: 0.0000 | Episode: 140 | Step: 3287 | Reward: 21.72 | Max : 39.48
# Alpha: 0.0000 | Episode: 141 | Step: 3312 | Reward: 20.01 | Max : 39.48
# Alpha: 0.0000 | Episode: 142 | Step: 3333 | Reward: 16.59 | Max : 39.48
# Alpha: 0.0000 | Episode: 143 | Step: 3354 | Reward: 16.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 144 | Step: 3371 | Reward: 13.31 | Max : 39.48
# Alpha: 0.0000 | Episode: 145 | Step: 3397 | Reward: 18.61 | Max : 39.48
# Alpha: 0.0000 | Episode: 146 | Step: 3415 | Reward: 14.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 147 | Step: 3433 | Reward: 14.31 | Max : 39.48
# Alpha: 0.0000 | Episode: 148 | Step: 3451 | Reward: 14.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 149 | Step: 3494 | Reward: 35.28 | Max : 39.48
# Alpha: 0.0000 | Episode: 150 | Step: 3511 | Reward: 13.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 151 | Step: 3541 | Reward: 22.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 152 | Step: 3557 | Reward: 12.39 | Max : 39.48
# Alpha: 0.0000 | Episode: 153 | Step: 3587 | Reward: 23.98 | Max : 39.48
# Alpha: 0.0000 | Episode: 154 | Step: 3606 | Reward: 15.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 155 | Step: 3630 | Reward: 18.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 156 | Step: 3648 | Reward: 14.18 | Max : 39.48
# Alpha: 0.0000 | Episode: 157 | Step: 3666 | Reward: 14.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 158 | Step: 3683 | Reward: 13.46 | Max : 39.48
# Alpha: 0.0000 | Episode: 159 | Step: 3719 | Reward: 28.87 | Max : 39.48
# Alpha: 0.0000 | Episode: 160 | Step: 3736 | Reward: 13.45 | Max : 39.48
# Alpha: 0.0000 | Episode: 161 | Step: 3754 | Reward: 14.35 | Max : 39.48
# Alpha: 0.0000 | Episode: 162 | Step: 3770 | Reward: 12.60 | Max : 39.48
# Alpha: 0.0000 | Episode: 163 | Step: 3794 | Reward: 19.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 164 | Step: 3830 | Reward: 27.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 165 | Step: 3859 | Reward: 23.26 | Max : 39.48
# Alpha: 0.0000 | Episode: 166 | Step: 3886 | Reward: 21.34 | Max : 39.48
# Alpha: 0.0000 | Episode: 167 | Step: 3907 | Reward: 16.68 | Max : 39.48
# Alpha: 0.0000 | Episode: 168 | Step: 3932 | Reward: 18.89 | Max : 39.48
# Alpha: 0.0000 | Episode: 169 | Step: 3956 | Reward: 19.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 170 | Step: 3977 | Reward: 16.45 | Max : 39.48
# Alpha: 0.0000 | Episode: 171 | Step: 3994 | Reward: 13.47 | Max : 39.48
# Alpha: 0.0000 | Episode: 172 | Step: 4015 | Reward: 16.52 | Max : 39.48
# Alpha: 0.0000 | Episode: 173 | Step: 4033 | Reward: 14.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 174 | Step: 4061 | Reward: 22.70 | Max : 39.48
# Alpha: 0.0000 | Episode: 175 | Step: 4080 | Reward: 15.05 | Max : 39.48
# Alpha: 0.0000 | Episode: 176 | Step: 4098 | Reward: 14.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 177 | Step: 4120 | Reward: 17.45 | Max : 39.48
# Alpha: 0.0000 | Episode: 178 | Step: 4141 | Reward: 15.53 | Max : 39.48
# Alpha: 0.0000 | Episode: 179 | Step: 4159 | Reward: 14.15 | Max : 39.48
# Alpha: 0.0000 | Episode: 180 | Step: 4184 | Reward: 20.02 | Max : 39.48
# Alpha: 0.0000 | Episode: 181 | Step: 4212 | Reward: 20.02 | Max : 39.48
# Alpha: 0.0000 | Episode: 182 | Step: 4231 | Reward: 15.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 183 | Step: 4252 | Reward: 16.58 | Max : 39.48
# Alpha: 0.0000 | Episode: 184 | Step: 4292 | Reward: 32.35 | Max : 39.48
# Alpha: 0.0000 | Episode: 185 | Step: 4310 | Reward: 13.93 | Max : 39.48
# Alpha: 0.0000 | Episode: 186 | Step: 4330 | Reward: 15.77 | Max : 39.48
# Alpha: 0.0000 | Episode: 187 | Step: 4358 | Reward: 22.56 | Max : 39.48
# Alpha: 0.0000 | Episode: 188 | Step: 4374 | Reward: 12.68 | Max : 39.48
# Alpha: 0.0000 | Episode: 189 | Step: 4392 | Reward: 14.11 | Max : 39.48
# Alpha: 0.0000 | Episode: 190 | Step: 4414 | Reward: 17.44 | Max : 39.48
# Alpha: 0.0000 | Episode: 191 | Step: 4438 | Reward: 18.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 192 | Step: 4459 | Reward: 16.74 | Max : 39.48
# Alpha: 0.0000 | Episode: 193 | Step: 4476 | Reward: 13.51 | Max : 39.48
# Alpha: 0.0000 | Episode: 194 | Step: 4494 | Reward: 14.28 | Max : 39.48
# Alpha: 0.0000 | Episode: 195 | Step: 4523 | Reward: 21.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 196 | Step: 4541 | Reward: 14.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 197 | Step: 4568 | Reward: 18.42 | Max : 39.48
# Alpha: 0.0000 | Episode: 198 | Step: 4586 | Reward: 13.90 | Max : 39.48
# Alpha: 0.0000 | Episode: 199 | Step: 4603 | Reward: 13.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 200 | Step: 4633 | Reward: 21.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 201 | Step: 4653 | Reward: 15.98 | Max : 39.48
# Alpha: 0.0000 | Episode: 202 | Step: 4673 | Reward: 15.96 | Max : 39.48
# Alpha: 0.0000 | Episode: 203 | Step: 4690 | Reward: 13.24 | Max : 39.48
# Alpha: 0.0000 | Episode: 204 | Step: 4725 | Reward: 27.46 | Max : 39.48
# Alpha: 0.0000 | Episode: 205 | Step: 4762 | Reward: 28.30 | Max : 39.48
# Alpha: 0.0000 | Episode: 206 | Step: 4780 | Reward: 14.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 207 | Step: 4800 | Reward: 14.97 | Max : 39.48
# Alpha: 0.0000 | Episode: 208 | Step: 4823 | Reward: 17.89 | Max : 39.48
# Alpha: 0.0000 | Episode: 209 | Step: 4858 | Reward: 27.44 | Max : 39.48
# Alpha: 0.0000 | Episode: 210 | Step: 4876 | Reward: 13.98 | Max : 39.48
# Alpha: 0.0000 | Episode: 211 | Step: 4899 | Reward: 17.61 | Max : 39.48
# Alpha: 0.0000 | Episode: 212 | Step: 4920 | Reward: 16.99 | Max : 39.48
# Alpha: 0.0000 | Episode: 213 | Step: 4954 | Reward: 26.46 | Max : 39.48
# Alpha: 0.0000 | Episode: 214 | Step: 4972 | Reward: 13.86 | Max : 39.48
# Alpha: 0.0000 | Episode: 215 | Step: 5000 | Reward: 21.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 216 | Step: 5017 | Reward: 13.23 | Max : 39.48
# Alpha: 0.0000 | Episode: 217 | Step: 5035 | Reward: 14.23 | Max : 39.48
# Alpha: 0.0000 | Episode: 218 | Step: 5078 | Reward: 32.33 | Max : 39.48
# Alpha: 0.0000 | Episode: 219 | Step: 5097 | Reward: 14.89 | Max : 39.48
# Alpha: 0.0000 | Episode: 220 | Step: 5116 | Reward: 15.05 | Max : 39.48
# Alpha: 0.0000 | Episode: 221 | Step: 5138 | Reward: 16.89 | Max : 39.48
# Alpha: 0.0000 | Episode: 222 | Step: 5155 | Reward: 13.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 223 | Step: 5180 | Reward: 19.94 | Max : 39.48
# Alpha: 0.0000 | Episode: 224 | Step: 5206 | Reward: 18.47 | Max : 39.48
# Alpha: 0.0000 | Episode: 225 | Step: 5226 | Reward: 15.83 | Max : 39.48
# Alpha: 0.0000 | Episode: 226 | Step: 5243 | Reward: 13.48 | Max : 39.48
# Alpha: 0.0000 | Episode: 227 | Step: 5269 | Reward: 19.65 | Max : 39.48
# Alpha: 0.0000 | Episode: 228 | Step: 5290 | Reward: 16.42 | Max : 39.48
# Alpha: 0.0000 | Episode: 229 | Step: 5312 | Reward: 17.54 | Max : 39.48
# Alpha: 0.0000 | Episode: 230 | Step: 5333 | Reward: 16.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 231 | Step: 5350 | Reward: 13.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 232 | Step: 5371 | Reward: 16.73 | Max : 39.48
# Alpha: 0.0000 | Episode: 233 | Step: 5392 | Reward: 16.05 | Max : 39.48
# Alpha: 0.0000 | Episode: 234 | Step: 5409 | Reward: 13.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 235 | Step: 5445 | Reward: 28.88 | Max : 39.48
# Alpha: 0.0000 | Episode: 236 | Step: 5462 | Reward: 13.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 237 | Step: 5479 | Reward: 13.33 | Max : 39.48
# Alpha: 0.0000 | Episode: 238 | Step: 5496 | Reward: 13.25 | Max : 39.48
# Alpha: 0.0000 | Episode: 239 | Step: 5518 | Reward: 18.14 | Max : 39.48
# Alpha: 0.0000 | Episode: 240 | Step: 5540 | Reward: 17.98 | Max : 39.48
# Alpha: 0.0000 | Episode: 241 | Step: 5560 | Reward: 15.84 | Max : 39.48
# Alpha: 0.0000 | Episode: 242 | Step: 5582 | Reward: 17.85 | Max : 39.48
# Alpha: 0.0000 | Episode: 243 | Step: 5613 | Reward: 24.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 244 | Step: 5639 | Reward: 19.62 | Max : 39.48
# Alpha: 0.0000 | Episode: 245 | Step: 5665 | Reward: 19.93 | Max : 39.48
# Alpha: 0.0000 | Episode: 246 | Step: 5685 | Reward: 15.80 | Max : 39.48
# Alpha: 0.0000 | Episode: 247 | Step: 5705 | Reward: 15.56 | Max : 39.48
# Alpha: 0.0000 | Episode: 248 | Step: 5723 | Reward: 14.29 | Max : 39.48
# Alpha: 0.0000 | Episode: 249 | Step: 5740 | Reward: 13.31 | Max : 39.48
# Alpha: 0.0000 | Episode: 250 | Step: 5758 | Reward: 14.01 | Max : 39.48
# Alpha: 0.0000 | Episode: 251 | Step: 5775 | Reward: 13.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 252 | Step: 5795 | Reward: 15.25 | Max : 39.48
# Alpha: 0.0000 | Episode: 253 | Step: 5828 | Reward: 25.37 | Max : 39.48
# Alpha: 0.0000 | Episode: 254 | Step: 5845 | Reward: 13.25 | Max : 39.48
# Alpha: 0.0000 | Episode: 255 | Step: 5863 | Reward: 14.35 | Max : 39.48
# Alpha: 0.0000 | Episode: 256 | Step: 5889 | Reward: 18.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 257 | Step: 5920 | Reward: 23.65 | Max : 39.48
# Alpha: 0.0000 | Episode: 258 | Step: 5937 | Reward: 13.34 | Max : 39.48
# Alpha: 0.0000 | Episode: 259 | Step: 5956 | Reward: 15.01 | Max : 39.48
# Alpha: 0.0000 | Episode: 260 | Step: 5974 | Reward: 14.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 261 | Step: 5992 | Reward: 14.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 262 | Step: 6014 | Reward: 17.28 | Max : 39.48
# Alpha: 0.0000 | Episode: 263 | Step: 6031 | Reward: 13.51 | Max : 39.48
# Alpha: 0.0000 | Episode: 264 | Step: 6053 | Reward: 15.77 | Max : 39.48
# Alpha: 0.0000 | Episode: 265 | Step: 6083 | Reward: 23.53 | Max : 39.48
# Alpha: 0.0000 | Episode: 266 | Step: 6101 | Reward: 13.83 | Max : 39.48
# Alpha: 0.0000 | Episode: 267 | Step: 6137 | Reward: 25.77 | Max : 39.48
# Alpha: 0.0000 | Episode: 268 | Step: 6154 | Reward: 13.45 | Max : 39.48
# Alpha: 0.0000 | Episode: 269 | Step: 6171 | Reward: 13.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 270 | Step: 6191 | Reward: 15.79 | Max : 39.48
# Alpha: 0.0000 | Episode: 271 | Step: 6209 | Reward: 14.00 | Max : 39.48
# Alpha: 0.0000 | Episode: 272 | Step: 6225 | Reward: 12.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 273 | Step: 6258 | Reward: 25.96 | Max : 39.48
# Alpha: 0.0000 | Episode: 274 | Step: 6276 | Reward: 14.02 | Max : 39.48
# Alpha: 0.0000 | Episode: 275 | Step: 6301 | Reward: 19.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 276 | Step: 6325 | Reward: 18.94 | Max : 39.48
# Alpha: 0.0000 | Episode: 277 | Step: 6343 | Reward: 14.32 | Max : 39.48
# Alpha: 0.0000 | Episode: 278 | Step: 6363 | Reward: 15.59 | Max : 39.48
# Alpha: 0.0000 | Episode: 279 | Step: 6390 | Reward: 20.84 | Max : 39.48
# Alpha: 0.0000 | Episode: 280 | Step: 6408 | Reward: 14.39 | Max : 39.48
# Alpha: 0.0000 | Episode: 281 | Step: 6434 | Reward: 20.51 | Max : 39.48
# Alpha: 0.0000 | Episode: 282 | Step: 6462 | Reward: 20.92 | Max : 39.48
# Alpha: 0.0000 | Episode: 283 | Step: 6488 | Reward: 20.36 | Max : 39.48
# Alpha: 0.0000 | Episode: 284 | Step: 6522 | Reward: 23.67 | Max : 39.48
# Alpha: 0.0000 | Episode: 285 | Step: 6560 | Reward: 29.76 | Max : 39.48
# Alpha: 0.0000 | Episode: 286 | Step: 6594 | Reward: 26.85 | Max : 39.48
# Alpha: 0.0000 | Episode: 287 | Step: 6617 | Reward: 18.68 | Max : 39.48
# Alpha: 0.0000 | Episode: 288 | Step: 6637 | Reward: 15.91 | Max : 39.48
# Alpha: 0.0000 | Episode: 289 | Step: 6658 | Reward: 16.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 290 | Step: 6682 | Reward: 19.06 | Max : 39.48
# Alpha: 0.0000 | Episode: 291 | Step: 6700 | Reward: 14.23 | Max : 39.48
# Alpha: 0.0000 | Episode: 292 | Step: 6740 | Reward: 29.99 | Max : 39.48
# Alpha: 0.0000 | Episode: 293 | Step: 6757 | Reward: 13.29 | Max : 39.48
# Alpha: 0.0000 | Episode: 294 | Step: 6782 | Reward: 19.55 | Max : 39.48
# Alpha: 0.0000 | Episode: 295 | Step: 6806 | Reward: 18.29 | Max : 39.48
# Alpha: 0.0000 | Episode: 296 | Step: 6823 | Reward: 13.24 | Max : 39.48
# Alpha: 0.0000 | Episode: 297 | Step: 6840 | Reward: 13.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 298 | Step: 6864 | Reward: 19.24 | Max : 39.48
# Alpha: 0.0000 | Episode: 299 | Step: 6897 | Reward: 26.21 | Max : 39.48
# Alpha: 0.0000 | Episode: 300 | Step: 6926 | Reward: 21.83 | Max : 39.48
# Alpha: 0.0000 | Episode: 301 | Step: 6967 | Reward: 32.84 | Max : 39.48
# Alpha: 0.0000 | Episode: 302 | Step: 6999 | Reward: 24.02 | Max : 39.48
# Alpha: 0.0000 | Episode: 303 | Step: 7035 | Reward: 27.59 | Max : 39.48
# Alpha: 0.0000 | Episode: 304 | Step: 7052 | Reward: 13.49 | Max : 39.48
# Alpha: 0.0000 | Episode: 305 | Step: 7071 | Reward: 15.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 306 | Step: 7091 | Reward: 15.47 | Max : 39.48
# Alpha: 0.0000 | Episode: 307 | Step: 7123 | Reward: 23.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 308 | Step: 7144 | Reward: 17.03 | Max : 39.48
# Alpha: 0.0000 | Episode: 309 | Step: 7173 | Reward: 21.90 | Max : 39.48
# Alpha: 0.0000 | Episode: 310 | Step: 7195 | Reward: 17.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 311 | Step: 7222 | Reward: 20.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 312 | Step: 7249 | Reward: 21.46 | Max : 39.48
# Alpha: 0.0000 | Episode: 313 | Step: 7269 | Reward: 15.61 | Max : 39.48
# Alpha: 0.0000 | Episode: 314 | Step: 7297 | Reward: 22.11 | Max : 39.48
# Alpha: 0.0000 | Episode: 315 | Step: 7335 | Reward: 29.48 | Max : 39.48
# Alpha: 0.0000 | Episode: 316 | Step: 7356 | Reward: 16.81 | Max : 39.48
# Alpha: 0.0000 | Episode: 317 | Step: 7377 | Reward: 16.20 | Max : 39.48
# Alpha: 0.0000 | Episode: 318 | Step: 7395 | Reward: 14.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 319 | Step: 7427 | Reward: 23.05 | Max : 39.48
# Alpha: 0.0000 | Episode: 320 | Step: 7454 | Reward: 20.70 | Max : 39.48
# Alpha: 0.0000 | Episode: 321 | Step: 7501 | Reward: 35.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 322 | Step: 7520 | Reward: 15.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 323 | Step: 7541 | Reward: 16.12 | Max : 39.48
# Alpha: 0.0000 | Episode: 324 | Step: 7561 | Reward: 15.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 325 | Step: 7580 | Reward: 14.89 | Max : 39.48
# Alpha: 0.0000 | Episode: 326 | Step: 7610 | Reward: 21.45 | Max : 39.48
# Alpha: 0.0000 | Episode: 327 | Step: 7635 | Reward: 20.37 | Max : 39.48
# Alpha: 0.0000 | Episode: 328 | Step: 7653 | Reward: 14.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 329 | Step: 7677 | Reward: 19.08 | Max : 39.48
# Alpha: 0.0000 | Episode: 330 | Step: 7695 | Reward: 13.95 | Max : 39.48
# Alpha: 0.0000 | Episode: 331 | Step: 7716 | Reward: 16.74 | Max : 39.48
# Alpha: 0.0000 | Episode: 332 | Step: 7739 | Reward: 18.51 | Max : 39.48
# Alpha: 0.0000 | Episode: 333 | Step: 7760 | Reward: 16.66 | Max : 39.48
# Alpha: 0.0000 | Episode: 334 | Step: 7778 | Reward: 14.00 | Max : 39.48
# Alpha: 0.0000 | Episode: 335 | Step: 7796 | Reward: 14.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 336 | Step: 7817 | Reward: 16.91 | Max : 39.48
# Alpha: 0.0000 | Episode: 337 | Step: 7847 | Reward: 23.97 | Max : 39.48
# Alpha: 0.0000 | Episode: 338 | Step: 7864 | Reward: 13.37 | Max : 39.48
# Alpha: 0.0000 | Episode: 339 | Step: 7901 | Reward: 28.63 | Max : 39.48
# Alpha: 0.0000 | Episode: 340 | Step: 7941 | Reward: 31.83 | Max : 39.48
# Alpha: 0.0000 | Episode: 341 | Step: 7964 | Reward: 16.93 | Max : 39.48
# Alpha: 0.0000 | Episode: 342 | Step: 7987 | Reward: 18.16 | Max : 39.48
# Alpha: 0.0000 | Episode: 343 | Step: 8015 | Reward: 21.34 | Max : 39.48
# Alpha: 0.0000 | Episode: 344 | Step: 8042 | Reward: 21.70 | Max : 39.48
# Alpha: 0.0000 | Episode: 345 | Step: 8067 | Reward: 20.03 | Max : 39.48
# Alpha: 0.0000 | Episode: 346 | Step: 8105 | Reward: 29.65 | Max : 39.48
# Alpha: 0.0000 | Episode: 347 | Step: 8123 | Reward: 14.14 | Max : 39.48
# Alpha: 0.0000 | Episode: 348 | Step: 8159 | Reward: 27.88 | Max : 39.48
# Alpha: 0.0000 | Episode: 349 | Step: 8178 | Reward: 14.88 | Max : 39.48
# Alpha: 0.0000 | Episode: 350 | Step: 8198 | Reward: 15.57 | Max : 39.48
# Alpha: 0.0000 | Episode: 351 | Step: 8215 | Reward: 13.26 | Max : 39.48
# Alpha: 0.0000 | Episode: 352 | Step: 8249 | Reward: 25.76 | Max : 39.48
# Alpha: 0.0000 | Episode: 353 | Step: 8273 | Reward: 19.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 354 | Step: 8291 | Reward: 14.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 355 | Step: 8314 | Reward: 17.51 | Max : 39.48
# Alpha: 0.0000 | Episode: 356 | Step: 8334 | Reward: 15.75 | Max : 39.48
# Alpha: 0.0000 | Episode: 357 | Step: 8377 | Reward: 32.95 | Max : 39.48
# Alpha: 0.0000 | Episode: 358 | Step: 8407 | Reward: 24.67 | Max : 39.48
# Alpha: 0.0000 | Episode: 359 | Step: 8427 | Reward: 14.52 | Max : 39.48
# Alpha: 0.0000 | Episode: 360 | Step: 8444 | Reward: 13.23 | Max : 39.48
# Alpha: 0.0000 | Episode: 361 | Step: 8466 | Reward: 16.62 | Max : 39.48
# Alpha: 0.0000 | Episode: 362 | Step: 8501 | Reward: 25.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 363 | Step: 8522 | Reward: 17.25 | Max : 39.48
# Alpha: 0.0000 | Episode: 364 | Step: 8541 | Reward: 14.81 | Max : 39.48
# Alpha: 0.0000 | Episode: 365 | Step: 8558 | Reward: 13.37 | Max : 39.48
# Alpha: 0.0000 | Episode: 366 | Step: 8576 | Reward: 13.87 | Max : 39.48
# Alpha: 0.0000 | Episode: 367 | Step: 8593 | Reward: 13.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 368 | Step: 8611 | Reward: 14.17 | Max : 39.48
# Alpha: 0.0000 | Episode: 369 | Step: 8630 | Reward: 15.14 | Max : 39.48
# Alpha: 0.0000 | Episode: 370 | Step: 8647 | Reward: 13.33 | Max : 39.48
# Alpha: 0.0000 | Episode: 371 | Step: 8671 | Reward: 18.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 372 | Step: 8688 | Reward: 13.42 | Max : 39.48
# Alpha: 0.0000 | Episode: 373 | Step: 8708 | Reward: 15.85 | Max : 39.48
# Alpha: 0.0000 | Episode: 374 | Step: 8727 | Reward: 14.88 | Max : 39.48
# Alpha: 0.0000 | Episode: 375 | Step: 8743 | Reward: 12.60 | Max : 39.48
# Alpha: 0.0000 | Episode: 376 | Step: 8760 | Reward: 13.15 | Max : 39.48
# Alpha: 0.0000 | Episode: 377 | Step: 8788 | Reward: 22.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 378 | Step: 8806 | Reward: 14.15 | Max : 39.48
# Alpha: 0.0000 | Episode: 379 | Step: 8824 | Reward: 13.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 380 | Step: 8859 | Reward: 24.67 | Max : 39.48
# Alpha: 0.0000 | Episode: 381 | Step: 8892 | Reward: 22.83 | Max : 39.48
# Alpha: 0.0000 | Episode: 382 | Step: 8915 | Reward: 18.28 | Max : 39.48
# Alpha: 0.0000 | Episode: 383 | Step: 8946 | Reward: 22.77 | Max : 39.48
# Alpha: 0.0000 | Episode: 384 | Step: 8969 | Reward: 18.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 385 | Step: 9003 | Reward: 25.48 | Max : 39.48
# Alpha: 0.0000 | Episode: 386 | Step: 9038 | Reward: 25.61 | Max : 39.48
# Alpha: 0.0000 | Episode: 387 | Step: 9058 | Reward: 15.41 | Max : 39.48
# Alpha: 0.0000 | Episode: 388 | Step: 9092 | Reward: 26.78 | Max : 39.48
# Alpha: 0.0000 | Episode: 389 | Step: 9116 | Reward: 19.25 | Max : 39.48
# Alpha: 0.0000 | Episode: 390 | Step: 9157 | Reward: 32.96 | Max : 39.48
# Alpha: 0.0000 | Episode: 391 | Step: 9190 | Reward: 26.53 | Max : 39.48
# Alpha: 0.0000 | Episode: 392 | Step: 9224 | Reward: 27.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 393 | Step: 9242 | Reward: 14.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 394 | Step: 9265 | Reward: 18.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 395 | Step: 9290 | Reward: 19.99 | Max : 39.48
# Alpha: 0.0000 | Episode: 396 | Step: 9307 | Reward: 13.27 | Max : 39.48
# Alpha: 0.0000 | Episode: 397 | Step: 9340 | Reward: 24.49 | Max : 39.48
# Alpha: 0.0000 | Episode: 398 | Step: 9374 | Reward: 26.12 | Max : 39.48
# Alpha: 0.0000 | Episode: 399 | Step: 9394 | Reward: 15.50 | Max : 39.48
# Alpha: 0.0000 | Episode: 400 | Step: 9415 | Reward: 16.67 | Max : 39.48
# Alpha: 0.0000 | Episode: 401 | Step: 9434 | Reward: 15.21 | Max : 39.48
# Alpha: 0.0000 | Episode: 402 | Step: 9465 | Reward: 25.63 | Max : 39.48
# Alpha: 0.0000 | Episode: 403 | Step: 9485 | Reward: 15.35 | Max : 39.48
# Alpha: 0.0000 | Episode: 404 | Step: 9515 | Reward: 22.04 | Max : 39.48
# Alpha: 0.0000 | Episode: 405 | Step: 9535 | Reward: 15.58 | Max : 39.48
# Alpha: 0.0000 | Episode: 406 | Step: 9553 | Reward: 14.20 | Max : 39.48
# Alpha: 0.0000 | Episode: 407 | Step: 9580 | Reward: 22.02 | Max : 39.48
# Alpha: 0.0000 | Episode: 408 | Step: 9622 | Reward: 31.40 | Max : 39.48
# Alpha: 0.0000 | Episode: 409 | Step: 9638 | Reward: 12.20 | Max : 39.48
# Alpha: 0.0000 | Episode: 410 | Step: 9661 | Reward: 17.56 | Max : 39.48
# Alpha: 0.0000 | Episode: 411 | Step: 9698 | Reward: 28.27 | Max : 39.48
# Alpha: 0.0000 | Episode: 412 | Step: 9716 | Reward: 14.03 | Max : 39.48
# Alpha: 0.0000 | Episode: 413 | Step: 9757 | Reward: 32.21 | Max : 39.48
# Alpha: 0.0000 | Episode: 414 | Step: 9773 | Reward: 12.34 | Max : 39.48
# Alpha: 0.0000 | Episode: 415 | Step: 9790 | Reward: 13.41 | Max : 39.48
# Alpha: 0.0000 | Episode: 416 | Step: 9808 | Reward: 14.26 | Max : 39.48
# Alpha: 0.0000 | Episode: 417 | Step: 9831 | Reward: 18.79 | Max : 39.48
# Alpha: 0.0000 | Episode: 418 | Step: 9848 | Reward: 13.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 419 | Step: 9868 | Reward: 15.50 | Max : 39.48
# Alpha: 0.0000 | Episode: 420 | Step: 9894 | Reward: 20.49 | Max : 39.48
# Alpha: 0.0000 | Episode: 421 | Step: 9911 | Reward: 13.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 422 | Step: 9945 | Reward: 25.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 423 | Step: 9964 | Reward: 15.10 | Max : 39.48
# Alpha: 0.0000 | Episode: 424 | Step: 9980 | Reward: 12.26 | Max : 39.48
# Alpha: 0.0000 | Episode: 425 | Step: 9999 | Reward: 15.13 | Max : 39.48
# Alpha: 0.0000 | Episode: 426 | Step: 10021 | Reward: 17.87 | Max : 39.48
# Alpha: 0.0000 | Episode: 427 | Step: 10038 | Reward: 13.41 | Max : 39.48
# Alpha: 0.0000 | Episode: 428 | Step: 10060 | Reward: 16.60 | Max : 39.48
# Alpha: 0.0000 | Episode: 429 | Step: 10087 | Reward: 21.19 | Max : 39.48
# Alpha: 0.0000 | Episode: 430 | Step: 10105 | Reward: 14.07 | Max : 39.48
# Alpha: 0.0000 | Episode: 431 | Step: 10126 | Reward: 16.84 | Max : 39.48
# Alpha: 0.0000 | Episode: 432 | Step: 10143 | Reward: 13.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 433 | Step: 10160 | Reward: 13.43 | Max : 39.48
# Alpha: 0.0000 | Episode: 434 | Step: 10199 | Reward: 32.22 | Max : 39.48
# Alpha: 0.0000 | Episode: 435 | Step: 10217 | Reward: 14.26 | Max : 39.48
# Alpha: 0.2000 | Episode: 436 | Step: 10254 | Reward: 29.54 | Max : 39.48
# Alpha: 0.2000 | Episode: 437 | Step: 10290 | Reward: 28.30 | Max : 39.48
# Alpha: 0.2000 | Episode: 438 | Step: 10317 | Reward: 19.53 | Max : 39.48
# Alpha: 0.2000 | Episode: 439 | Step: 10341 | Reward: 19.10 | Max : 39.48
# Alpha: 0.2000 | Episode: 440 | Step: 10360 | Reward: 14.85 | Max : 39.48
# Alpha: 0.2000 | Episode: 441 | Step: 10384 | Reward: 18.51 | Max : 39.48
# Alpha: 0.2000 | Episode: 442 | Step: 10402 | Reward: 14.12 | Max : 39.48
# Alpha: 0.2000 | Episode: 443 | Step: 10420 | Reward: 14.11 | Max : 39.48
# Alpha: 0.2000 | Episode: 444 | Step: 10454 | Reward: 24.77 | Max : 39.48
# Alpha: 0.2000 | Episode: 445 | Step: 10478 | Reward: 18.71 | Max : 39.48
# Alpha: 0.2000 | Episode: 446 | Step: 10498 | Reward: 16.18 | Max : 39.48
# Alpha: 0.2000 | Episode: 447 | Step: 10517 | Reward: 14.75 | Max : 39.48
# Alpha: 0.2000 | Episode: 448 | Step: 10546 | Reward: 22.90 | Max : 39.48
# Alpha: 0.2000 | Episode: 449 | Step: 10574 | Reward: 22.23 | Max : 39.48
# Alpha: 0.2000 | Episode: 450 | Step: 10592 | Reward: 14.33 | Max : 39.48
# Alpha: 0.2000 | Episode: 451 | Step: 10609 | Reward: 13.40 | Max : 39.48
# Alpha: 0.2000 | Episode: 452 | Step: 10626 | Reward: 13.26 | Max : 39.48
# Alpha: 0.2000 | Episode: 453 | Step: 10657 | Reward: 23.16 | Max : 39.48
# Alpha: 0.2000 | Episode: 454 | Step: 10680 | Reward: 17.81 | Max : 39.48
# Alpha: 0.2000 | Episode: 455 | Step: 10701 | Reward: 16.94 | Max : 39.48
# Alpha: 0.2000 | Episode: 456 | Step: 10718 | Reward: 13.41 | Max : 39.48
# Alpha: 0.2000 | Episode: 457 | Step: 10738 | Reward: 15.53 | Max : 39.48
# Alpha: 0.2000 | Episode: 458 | Step: 10766 | Reward: 22.69 | Max : 39.48
# Alpha: 0.2000 | Episode: 459 | Step: 10786 | Reward: 15.91 | Max : 39.48
# Alpha: 0.2000 | Episode: 460 | Step: 10805 | Reward: 14.91 | Max : 39.48
# Alpha: 0.2000 | Episode: 461 | Step: 10824 | Reward: 15.07 | Max : 39.48
# Alpha: 0.2000 | Episode: 462 | Step: 10844 | Reward: 15.48 | Max : 39.48
# Alpha: 0.2000 | Episode: 463 | Step: 10864 | Reward: 15.65 | Max : 39.48
# Alpha: 0.2000 | Episode: 464 | Step: 10888 | Reward: 19.16 | Max : 39.48
# Alpha: 0.2000 | Episode: 465 | Step: 10905 | Reward: 13.48 | Max : 39.48
# Alpha: 0.2000 | Episode: 466 | Step: 10935 | Reward: 23.25 | Max : 39.48
# Alpha: 0.2000 | Episode: 467 | Step: 10955 | Reward: 16.04 | Max : 39.48
# Alpha: 0.2000 | Episode: 468 | Step: 10981 | Reward: 18.97 | Max : 39.48
# Alpha: 0.2000 | Episode: 469 | Step: 11000 | Reward: 15.09 | Max : 39.48
# Alpha: 0.2000 | Episode: 470 | Step: 11019 | Reward: 14.78 | Max : 39.48
# Alpha: 0.2000 | Episode: 471 | Step: 11037 | Reward: 13.94 | Max : 39.48
# Alpha: 0.2000 | Episode: 472 | Step: 11069 | Reward: 26.09 | Max : 39.48
# Alpha: 0.2000 | Episode: 473 | Step: 11090 | Reward: 16.46 | Max : 39.48
# Alpha: 0.2000 | Episode: 474 | Step: 11116 | Reward: 20.36 | Max : 39.48
# Alpha: 0.2000 | Episode: 475 | Step: 11136 | Reward: 16.18 | Max : 39.48
# Alpha: 0.2000 | Episode: 476 | Step: 11159 | Reward: 18.30 | Max : 39.48
# Alpha: 0.2000 | Episode: 477 | Step: 11183 | Reward: 18.84 | Max : 39.48
# Alpha: 0.2000 | Episode: 478 | Step: 11200 | Reward: 13.31 | Max : 39.48
# Alpha: 0.2000 | Episode: 479 | Step: 11227 | Reward: 22.11 | Max : 39.48
# Alpha: 0.2000 | Episode: 480 | Step: 11262 | Reward: 24.94 | Max : 39.48
# Alpha: 0.2000 | Episode: 481 | Step: 11293 | Reward: 21.74 | Max : 39.48
# Alpha: 0.2000 | Episode: 482 | Step: 11317 | Reward: 18.22 | Max : 39.48
# Alpha: 0.2000 | Episode: 483 | Step: 11334 | Reward: 13.13 | Max : 39.48
# Alpha: 0.2000 | Episode: 484 | Step: 11356 | Reward: 16.93 | Max : 39.48
# Alpha: 0.2000 | Episode: 485 | Step: 11375 | Reward: 15.10 | Max : 39.48
# Alpha: 0.2000 | Episode: 486 | Step: 11414 | Reward: 31.79 | Max : 39.48
# Alpha: 0.2000 | Episode: 487 | Step: 11434 | Reward: 15.63 | Max : 39.48
# Alpha: 0.2000 | Episode: 488 | Step: 11452 | Reward: 14.45 | Max : 39.48
# Alpha: 0.2000 | Episode: 489 | Step: 11486 | Reward: 27.69 | Max : 39.48
# Alpha: 0.2000 | Episode: 490 | Step: 11521 | Reward: 27.78 | Max : 39.48
# Alpha: 0.2000 | Episode: 491 | Step: 11550 | Reward: 20.30 | Max : 39.48
# Alpha: 0.2000 | Episode: 492 | Step: 11566 | Reward: 12.51 | Max : 39.48
# Alpha: 0.2000 | Episode: 493 | Step: 11598 | Reward: 25.85 | Max : 39.48
# Alpha: 0.2000 | Episode: 494 | Step: 11620 | Reward: 17.05 | Max : 39.48
# Alpha: 0.2000 | Episode: 495 | Step: 11642 | Reward: 17.32 | Max : 39.48
# Alpha: 0.2000 | Episode: 496 | Step: 11674 | Reward: 23.52 | Max : 39.48
# Alpha: 0.2000 | Episode: 497 | Step: 11691 | Reward: 13.16 | Max : 39.48
# Alpha: 0.2000 | Episode: 498 | Step: 11720 | Reward: 20.42 | Max : 39.48
# Alpha: 0.2000 | Episode: 499 | Step: 11751 | Reward: 24.54 | Max : 39.48
# Alpha: 0.2000 | Episode: 500 | Step: 11778 | Reward: 21.72 | Max : 39.48
# Alpha: 0.2000 | Episode: 501 | Step: 11812 | Reward: 27.19 | Max : 39.48
# Alpha: 0.2000 | Episode: 502 | Step: 11831 | Reward: 14.96 | Max : 39.48
# Alpha: 0.2000 | Episode: 503 | Step: 11849 | Reward: 14.30 | Max : 39.48
# Alpha: 0.2000 | Episode: 504 | Step: 11867 | Reward: 13.92 | Max : 39.48
# Alpha: 0.2000 | Episode: 505 | Step: 11890 | Reward: 18.27 | Max : 39.48
# Alpha: 0.2000 | Episode: 506 | Step: 11922 | Reward: 22.30 | Max : 39.48
# Alpha: 0.2000 | Episode: 507 | Step: 11943 | Reward: 16.73 | Max : 39.48
# Alpha: 0.2000 | Episode: 508 | Step: 11960 | Reward: 13.16 | Max : 39.48
# Alpha: 0.2000 | Episode: 509 | Step: 11977 | Reward: 13.27 | Max : 39.48
# Alpha: 0.2000 | Episode: 510 | Step: 11999 | Reward: 17.70 | Max : 39.48
# Alpha: 0.2000 | Episode: 511 | Step: 12018 | Reward: 15.05 | Max : 39.48
# Alpha: 0.2000 | Episode: 512 | Step: 12036 | Reward: 14.38 | Max : 39.48
# Alpha: 0.2000 | Episode: 513 | Step: 12054 | Reward: 14.27 | Max : 39.48
# Alpha: 0.2000 | Episode: 514 | Step: 12074 | Reward: 15.85 | Max : 39.48
# Alpha: 0.2000 | Episode: 515 | Step: 12094 | Reward: 16.15 | Max : 39.48
# Alpha: 0.2000 | Episode: 516 | Step: 12113 | Reward: 15.14 | Max : 39.48
# Alpha: 0.2000 | Episode: 517 | Step: 12143 | Reward: 24.29 | Max : 39.48
# Alpha: 0.2000 | Episode: 518 | Step: 12169 | Reward: 19.15 | Max : 39.48
# Alpha: 0.2000 | Episode: 519 | Step: 12189 | Reward: 15.36 | Max : 39.48
# Alpha: 0.2000 | Episode: 520 | Step: 12209 | Reward: 16.13 | Max : 39.48
# Alpha: 0.2000 | Episode: 521 | Step: 12227 | Reward: 14.16 | Max : 39.48
# Alpha: 0.2000 | Episode: 522 | Step: 12245 | Reward: 14.20 | Max : 39.48
# Alpha: 0.2000 | Episode: 523 | Step: 12264 | Reward: 15.26 | Max : 39.48
# Alpha: 0.2000 | Episode: 524 | Step: 12295 | Reward: 24.82 | Max : 39.48
# Alpha: 0.2000 | Episode: 525 | Step: 12314 | Reward: 14.95 | Max : 39.48
# Alpha: 0.2000 | Episode: 526 | Step: 12331 | Reward: 13.44 | Max : 39.48
# Alpha: 0.2000 | Episode: 527 | Step: 12348 | Reward: 13.39 | Max : 39.48
# Alpha: 0.2000 | Episode: 528 | Step: 12379 | Reward: 24.75 | Max : 39.48
# Alpha: 0.2000 | Episode: 529 | Step: 12397 | Reward: 14.26 | Max : 39.48
# Alpha: 0.2000 | Episode: 530 | Step: 12427 | Reward: 23.18 | Max : 39.48
# Alpha: 0.2000 | Episode: 531 | Step: 12445 | Reward: 13.95 | Max : 39.48
# Alpha: 0.2000 | Episode: 532 | Step: 12485 | Reward: 29.63 | Max : 39.48
# Alpha: 0.2000 | Episode: 533 | Step: 12511 | Reward: 20.66 | Max : 39.48
# Alpha: 0.2000 | Episode: 534 | Step: 12529 | Reward: 14.35 | Max : 39.48
# Alpha: 0.2000 | Episode: 535 | Step: 12549 | Reward: 15.96 | Max : 39.48
# Alpha: 0.2000 | Episode: 536 | Step: 12565 | Reward: 12.36 | Max : 39.48
# Alpha: 0.2000 | Episode: 537 | Step: 12583 | Reward: 14.25 | Max : 39.48
# Alpha: 0.2000 | Episode: 538 | Step: 12600 | Reward: 13.29 | Max : 39.48
# Alpha: 0.2000 | Episode: 539 | Step: 12618 | Reward: 14.31 | Max : 39.48
# Alpha: 0.2000 | Episode: 540 | Step: 12645 | Reward: 21.57 | Max : 39.48
# Alpha: 0.2000 | Episode: 541 | Step: 12664 | Reward: 15.01 | Max : 39.48
# Alpha: 0.2000 | Episode: 542 | Step: 12681 | Reward: 13.38 | Max : 39.48
# Alpha: 0.2000 | Episode: 543 | Step: 12718 | Reward: 29.27 | Max : 39.48
# Alpha: 0.2000 | Episode: 544 | Step: 12750 | Reward: 23.98 | Max : 39.48
# Alpha: 0.2000 | Episode: 545 | Step: 12771 | Reward: 16.35 | Max : 39.48
# Alpha: 0.2000 | Episode: 546 | Step: 12820 | Reward: 37.70 | Max : 39.48
# Alpha: 0.2000 | Episode: 547 | Step: 12840 | Reward: 15.90 | Max : 39.48
# Alpha: 0.2000 | Episode: 548 | Step: 12857 | Reward: 13.11 | Max : 39.48
# Alpha: 0.2000 | Episode: 549 | Step: 12873 | Reward: 12.61 | Max : 39.48
# Alpha: 0.2000 | Episode: 550 | Step: 12898 | Reward: 19.34 | Max : 39.48
# Alpha: 0.2000 | Episode: 551 | Step: 12925 | Reward: 20.37 | Max : 39.48
# Alpha: 0.2000 | Episode: 552 | Step: 12944 | Reward: 14.91 | Max : 39.48
# Alpha: 0.2000 | Episode: 553 | Step: 12969 | Reward: 19.96 | Max : 39.48
# Alpha: 0.2000 | Episode: 554 | Step: 12991 | Reward: 17.49 | Max : 39.48
# Alpha: 0.2000 | Episode: 555 | Step: 13013 | Reward: 16.69 | Max : 39.48
# Alpha: 0.2000 | Episode: 556 | Step: 13032 | Reward: 14.99 | Max : 39.48
# Alpha: 0.2000 | Episode: 557 | Step: 13063 | Reward: 24.38 | Max : 39.48
# Alpha: 0.2000 | Episode: 558 | Step: 13092 | Reward: 23.34 | Max : 39.48
# Alpha: 0.2000 | Episode: 559 | Step: 13110 | Reward: 13.81 | Max : 39.48
# Alpha: 0.2000 | Episode: 560 | Step: 13132 | Reward: 17.29 | Max : 39.48
# Alpha: 0.2000 | Episode: 561 | Step: 13165 | Reward: 24.84 | Max : 39.48
# Alpha: 0.2000 | Episode: 562 | Step: 13182 | Reward: 13.50 | Max : 39.48
# Alpha: 0.2000 | Episode: 563 | Step: 13201 | Reward: 14.75 | Max : 39.48
# Alpha: 0.2000 | Episode: 564 | Step: 13218 | Reward: 13.51 | Max : 39.48
# Alpha: 0.2000 | Episode: 565 | Step: 13237 | Reward: 15.36 | Max : 39.48
# Alpha: 0.2000 | Episode: 566 | Step: 13255 | Reward: 14.21 | Max : 39.48
# Alpha: 0.2000 | Episode: 567 | Step: 13272 | Reward: 13.43 | Max : 39.48
# Alpha: 0.2000 | Episode: 568 | Step: 13292 | Reward: 15.94 | Max : 39.48
# Alpha: 0.2000 | Episode: 569 | Step: 13309 | Reward: 13.26 | Max : 39.48
# Alpha: 0.1999 | Episode: 570 | Step: 13327 | Reward: 14.28 | Max : 39.48
# Alpha: 0.1999 | Episode: 571 | Step: 13354 | Reward: 20.85 | Max : 39.48
# Alpha: 0.1999 | Episode: 572 | Step: 13385 | Reward: 23.36 | Max : 39.48
# Alpha: 0.1999 | Episode: 573 | Step: 13404 | Reward: 14.88 | Max : 39.48
# Alpha: 0.1999 | Episode: 574 | Step: 13421 | Reward: 13.38 | Max : 39.48
# Alpha: 0.1999 | Episode: 575 | Step: 13440 | Reward: 14.81 | Max : 39.48
# Alpha: 0.1999 | Episode: 576 | Step: 13493 | Reward: 42.27 | Max : 42.27
# Alpha: 0.1999 | Episode: 577 | Step: 13511 | Reward: 13.58 | Max : 42.27
# Alpha: 0.1999 | Episode: 578 | Step: 13529 | Reward: 14.06 | Max : 42.27
# Alpha: 0.1999 | Episode: 579 | Step: 13560 | Reward: 24.63 | Max : 42.27
# Alpha: 0.1999 | Episode: 580 | Step: 13578 | Reward: 14.16 | Max : 42.27
# Alpha: 0.1999 | Episode: 581 | Step: 13594 | Reward: 12.30 | Max : 42.27
# Alpha: 0.1999 | Episode: 582 | Step: 13614 | Reward: 15.69 | Max : 42.27
# Alpha: 0.1999 | Episode: 583 | Step: 13632 | Reward: 14.09 | Max : 42.27
# Alpha: 0.1999 | Episode: 584 | Step: 13649 | Reward: 13.25 | Max : 42.27
# Alpha: 0.1999 | Episode: 585 | Step: 13674 | Reward: 18.55 | Max : 42.27
# Alpha: 0.1999 | Episode: 586 | Step: 13709 | Reward: 25.60 | Max : 42.27
# Alpha: 0.1999 | Episode: 587 | Step: 13730 | Reward: 16.03 | Max : 42.27
# Alpha: 0.1999 | Episode: 588 | Step: 13762 | Reward: 24.51 | Max : 42.27
# Alpha: 0.1999 | Episode: 589 | Step: 13787 | Reward: 20.08 | Max : 42.27
# Alpha: 0.1999 | Episode: 590 | Step: 13827 | Reward: 29.28 | Max : 42.27
# Alpha: 0.1999 | Episode: 591 | Step: 13845 | Reward: 14.14 | Max : 42.27
# Alpha: 0.1999 | Episode: 592 | Step: 13871 | Reward: 20.02 | Max : 42.27
# Alpha: 0.1999 | Episode: 593 | Step: 13888 | Reward: 13.30 | Max : 42.27
# Alpha: 0.1999 | Episode: 594 | Step: 13905 | Reward: 13.46 | Max : 42.27
# Alpha: 0.1999 | Episode: 595 | Step: 13923 | Reward: 14.11 | Max : 42.27
# Alpha: 0.1999 | Episode: 596 | Step: 13940 | Reward: 13.52 | Max : 42.27
# Alpha: 0.1999 | Episode: 597 | Step: 13961 | Reward: 16.68 | Max : 42.27
# Alpha: 0.1999 | Episode: 598 | Step: 13981 | Reward: 15.82 | Max : 42.27
# Alpha: 0.1999 | Episode: 599 | Step: 13999 | Reward: 14.04 | Max : 42.27
# Alpha: 0.1999 | Episode: 600 | Step: 14020 | Reward: 16.55 | Max : 42.27
# Alpha: 0.1999 | Episode: 601 | Step: 14040 | Reward: 14.23 | Max : 42.27
# Alpha: 0.1999 | Episode: 602 | Step: 14066 | Reward: 19.94 | Max : 42.27
# Alpha: 0.1999 | Episode: 603 | Step: 14097 | Reward: 22.62 | Max : 42.27
# Alpha: 0.1999 | Episode: 604 | Step: 14114 | Reward: 13.13 | Max : 42.27
# Alpha: 0.1999 | Episode: 605 | Step: 14132 | Reward: 14.19 | Max : 42.27
# Alpha: 0.1999 | Episode: 606 | Step: 14153 | Reward: 16.54 | Max : 42.27
# Alpha: 0.1999 | Episode: 607 | Step: 14182 | Reward: 22.88 | Max : 42.27
# Alpha: 0.1999 | Episode: 608 | Step: 14200 | Reward: 14.06 | Max : 42.27
# Alpha: 0.1999 | Episode: 609 | Step: 14216 | Reward: 12.63 | Max : 42.27
# Alpha: 0.1999 | Episode: 610 | Step: 14233 | Reward: 13.25 | Max : 42.27
# Alpha: 0.1999 | Episode: 611 | Step: 14249 | Reward: 12.60 | Max : 42.27
# Alpha: 0.1999 | Episode: 612 | Step: 14283 | Reward: 26.87 | Max : 42.27
# Alpha: 0.1999 | Episode: 613 | Step: 14307 | Reward: 19.30 | Max : 42.27
# Alpha: 0.1999 | Episode: 614 | Step: 14327 | Reward: 15.17 | Max : 42.27
# Alpha: 0.1999 | Episode: 615 | Step: 14347 | Reward: 15.25 | Max : 42.27
# Alpha: 0.1999 | Episode: 616 | Step: 14364 | Reward: 13.37 | Max : 42.27
# Alpha: 0.1999 | Episode: 617 | Step: 14382 | Reward: 14.18 | Max : 42.27
# Alpha: 0.1999 | Episode: 618 | Step: 14411 | Reward: 23.39 | Max : 42.27
# Alpha: 0.1999 | Episode: 619 | Step: 14428 | Reward: 13.19 | Max : 42.27
# Alpha: 0.1999 | Episode: 620 | Step: 14451 | Reward: 18.38 | Max : 42.27
# Alpha: 0.1999 | Episode: 621 | Step: 14472 | Reward: 16.79 | Max : 42.27
# Alpha: 0.1999 | Episode: 622 | Step: 14489 | Reward: 13.21 | Max : 42.27
# Alpha: 0.1999 | Episode: 623 | Step: 14516 | Reward: 18.93 | Max : 42.27
# Alpha: 0.1999 | Episode: 624 | Step: 14542 | Reward: 18.90 | Max : 42.27
# Alpha: 0.1999 | Episode: 625 | Step: 14576 | Reward: 26.57 | Max : 42.27
# Alpha: 0.1999 | Episode: 626 | Step: 14596 | Reward: 15.96 | Max : 42.27
# Alpha: 0.1999 | Episode: 627 | Step: 14623 | Reward: 20.05 | Max : 42.27
# Alpha: 0.1999 | Episode: 628 | Step: 14648 | Reward: 20.18 | Max : 42.27
# Alpha: 0.1999 | Episode: 629 | Step: 14666 | Reward: 14.18 | Max : 42.27
# Alpha: 0.1999 | Episode: 630 | Step: 14684 | Reward: 14.08 | Max : 42.27
# Alpha: 0.1999 | Episode: 631 | Step: 14704 | Reward: 15.87 | Max : 42.27
# Alpha: 0.1999 | Episode: 632 | Step: 14732 | Reward: 22.30 | Max : 42.27
# Alpha: 0.1999 | Episode: 633 | Step: 14749 | Reward: 13.24 | Max : 42.27
# Alpha: 0.1999 | Episode: 634 | Step: 14774 | Reward: 19.53 | Max : 42.27
# Alpha: 0.1999 | Episode: 635 | Step: 14794 | Reward: 15.57 | Max : 42.27
# Alpha: 0.1999 | Episode: 636 | Step: 14811 | Reward: 13.44 | Max : 42.27
# Alpha: 0.1999 | Episode: 637 | Step: 14828 | Reward: 13.44 | Max : 42.27
# Alpha: 0.1999 | Episode: 638 | Step: 14862 | Reward: 26.32 | Max : 42.27
# Alpha: 0.1999 | Episode: 639 | Step: 14885 | Reward: 18.69 | Max : 42.27
# Alpha: 0.1999 | Episode: 640 | Step: 14903 | Reward: 14.32 | Max : 42.27
# Alpha: 0.1999 | Episode: 641 | Step: 14920 | Reward: 13.25 | Max : 42.27
# Alpha: 0.1999 | Episode: 642 | Step: 14947 | Reward: 21.54 | Max : 42.27
# Alpha: 0.1999 | Episode: 643 | Step: 14974 | Reward: 21.04 | Max : 42.27
# Alpha: 0.1999 | Episode: 644 | Step: 14997 | Reward: 18.25 | Max : 42.27
# Alpha: 0.1999 | Episode: 645 | Step: 15029 | Reward: 25.02 | Max : 42.27
# Alpha: 0.1999 | Episode: 646 | Step: 15054 | Reward: 18.38 | Max : 42.27
# Alpha: 0.1999 | Episode: 647 | Step: 15094 | Reward: 30.09 | Max : 42.27
# Alpha: 0.1999 | Episode: 648 | Step: 15112 | Reward: 13.77 | Max : 42.27
# Alpha: 0.1999 | Episode: 649 | Step: 15143 | Reward: 23.54 | Max : 42.27
# Alpha: 0.1999 | Episode: 650 | Step: 15166 | Reward: 18.12 | Max : 42.27
# Alpha: 0.1999 | Episode: 651 | Step: 15183 | Reward: 13.24 | Max : 42.27
# Alpha: 0.1999 | Episode: 652 | Step: 15215 | Reward: 23.03 | Max : 42.27
# Alpha: 0.1999 | Episode: 653 | Step: 15246 | Reward: 25.01 | Max : 42.27
# Alpha: 0.1999 | Episode: 654 | Step: 15266 | Reward: 15.14 | Max : 42.27
# Alpha: 0.1999 | Episode: 655 | Step: 15300 | Reward: 26.32 | Max : 42.27
# Alpha: 0.1999 | Episode: 656 | Step: 15331 | Reward: 24.06 | Max : 42.27
# Alpha: 0.1999 | Episode: 657 | Step: 15366 | Reward: 26.33 | Max : 42.27
# Alpha: 0.1999 | Episode: 658 | Step: 15384 | Reward: 14.35 | Max : 42.27
# Alpha: 0.1999 | Episode: 659 | Step: 15407 | Reward: 18.03 | Max : 42.27
# Alpha: 0.1999 | Episode: 660 | Step: 15424 | Reward: 13.21 | Max : 42.27
# Alpha: 0.1999 | Episode: 661 | Step: 15443 | Reward: 15.11 | Max : 42.27
# Alpha: 0.1999 | Episode: 662 | Step: 15461 | Reward: 14.10 | Max : 42.27
# Alpha: 0.1999 | Episode: 663 | Step: 15498 | Reward: 29.70 | Max : 42.27
# Alpha: 0.1999 | Episode: 664 | Step: 15519 | Reward: 16.50 | Max : 42.27
# ...
# Alpha: 0.1945 | Episode: 12949 | Step: 303688 | Reward: 13.46 | Max : 56.38
# Alpha: 0.1945 | Episode: 12950 | Step: 303705 | Reward: 13.44 | Max : 56.38
# Alpha: 0.1945 | Episode: 12951 | Step: 303722 | Reward: 13.32 | Max : 56.38
# Alpha: 0.1945 | Episode: 12952 | Step: 303742 | Reward: 14.78 | Max : 56.38
# Alpha: 0.1945 | Episode: 12953 | Step: 303762 | Reward: 15.61 | Max : 56.38
# Alpha: 0.1945 | Episode: 12954 | Step: 303792 | Reward: 23.78 | Max : 56.38
# Alpha: 0.1945 | Episode: 12955 | Step: 303841 | Reward: 39.26 | Max : 56.38
# Alpha: 0.1945 | Episode: 12956 | Step: 303867 | Reward: 20.55 | Max : 56.38
# Alpha: 0.1945 | Episode: 12957 | Step: 303886 | Reward: 15.08 | Max : 56.38
# Alpha: 0.1945 | Episode: 12958 | Step: 303905 | Reward: 15.10 | Max : 56.38
# Alpha: 0.1945 | Episode: 12959 | Step: 303927 | Reward: 17.05 | Max : 56.38
# Alpha: 0.1945 | Episode: 12960 | Step: 303957 | Reward: 23.98 | Max : 56.38
# Alpha: 0.1945 | Episode: 12961 | Step: 303985 | Reward: 22.75 | Max : 56.38
# Alpha: 0.1945 | Episode: 12962 | Step: 304013 | Reward: 22.83 | Max : 56.38
# Alpha: 0.1945 | Episode: 12963 | Step: 304031 | Reward: 13.90 | Max : 56.38
# Alpha: 0.1945 | Episode: 12964 | Step: 304055 | Reward: 18.55 | Max : 56.38
# Alpha: 0.1945 | Episode: 12965 | Step: 304081 | Reward: 20.34 | Max : 56.38
# Alpha: 0.1945 | Episode: 12966 | Step: 304099 | Reward: 14.28 | Max : 56.38
# Alpha: 0.1945 | Episode: 12967 | Step: 304116 | Reward: 12.79 | Max : 56.38
# Alpha: 0.1944 | Episode: 12968 | Step: 304134 | Reward: 14.28 | Max : 56.38
# Alpha: 0.1944 | Episode: 12969 | Step: 304152 | Reward: 14.16 | Max : 56.38
# Alpha: 0.1944 | Episode: 12970 | Step: 304169 | Reward: 13.43 | Max : 56.38
# Alpha: 0.1944 | Episode: 12971 | Step: 304215 | Reward: 36.56 | Max : 56.38
# Alpha: 0.1944 | Episode: 12972 | Step: 304233 | Reward: 14.33 | Max : 56.38
# Alpha: 0.1944 | Episode: 12973 | Step: 304257 | Reward: 19.48 | Max : 56.38
# Alpha: 0.1944 | Episode: 12974 | Step: 304283 | Reward: 20.59 | Max : 56.38
# Alpha: 0.1944 | Episode: 12975 | Step: 304303 | Reward: 15.73 | Max : 56.38
# Alpha: 0.1944 | Episode: 12976 | Step: 304319 | Reward: 12.26 | Max : 56.38
# Alpha: 0.1944 | Episode: 12977 | Step: 304336 | Reward: 13.37 | Max : 56.38
# Alpha: 0.1944 | Episode: 12978 | Step: 304368 | Reward: 25.80 | Max : 56.38
# Alpha: 0.1944 | Episode: 12979 | Step: 304385 | Reward: 13.50 | Max : 56.38
# Alpha: 0.1944 | Episode: 12980 | Step: 304408 | Reward: 18.63 | Max : 56.38
# Alpha: 0.1944 | Episode: 12981 | Step: 304440 | Reward: 24.13 | Max : 56.38
# Alpha: 0.1944 | Episode: 12982 | Step: 304466 | Reward: 20.32 | Max : 56.38
# Alpha: 0.1944 | Episode: 12983 | Step: 304489 | Reward: 18.52 | Max : 56.38
# Alpha: 0.1944 | Episode: 12984 | Step: 304508 | Reward: 14.86 | Max : 56.38
# Alpha: 0.1944 | Episode: 12985 | Step: 304533 | Reward: 20.25 | Max : 56.38
# Alpha: 0.1944 | Episode: 12986 | Step: 304550 | Reward: 13.44 | Max : 56.38
# Alpha: 0.1944 | Episode: 12987 | Step: 304591 | Reward: 31.44 | Max : 56.38
# Alpha: 0.1944 | Episode: 12988 | Step: 304609 | Reward: 14.25 | Max : 56.38
# Alpha: 0.1944 | Episode: 12989 | Step: 304634 | Reward: 19.49 | Max : 56.38
# Alpha: 0.1944 | Episode: 12990 | Step: 304653 | Reward: 14.28 | Max : 56.38
# Alpha: 0.1944 | Episode: 12991 | Step: 304671 | Reward: 14.16 | Max : 56.38
# Alpha: 0.1944 | Episode: 12992 | Step: 304689 | Reward: 14.10 | Max : 56.38
# Alpha: 0.1944 | Episode: 12993 | Step: 304713 | Reward: 18.73 | Max : 56.38
# Alpha: 0.1944 | Episode: 12994 | Step: 304740 | Reward: 20.32 | Max : 56.38
# Alpha: 0.1944 | Episode: 12995 | Step: 304767 | Reward: 21.22 | Max : 56.38
# Alpha: 0.1944 | Episode: 12996 | Step: 304786 | Reward: 14.70 | Max : 56.38
# Alpha: 0.1944 | Episode: 12997 | Step: 304809 | Reward: 18.06 | Max : 56.38
# Alpha: 0.1944 | Episode: 12998 | Step: 304833 | Reward: 18.64 | Max : 56.38
# Alpha: 0.1944 | Episode: 12999 | Step: 304861 | Reward: 21.67 | Max : 56.38
# Alpha: 0.1944 | Episode: 13000 | Step: 304881 | Reward: 15.41 | Max : 56.38
# Alpha: 0.1944 | Episode: 13001 | Step: 304911 | Reward: 21.43 | Max : 56.38
# Alpha: 0.1944 | Episode: 13002 | Step: 304929 | Reward: 14.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13003 | Step: 304949 | Reward: 15.81 | Max : 56.38
# Alpha: 0.1944 | Episode: 13004 | Step: 304966 | Reward: 13.33 | Max : 56.38
# Alpha: 0.1944 | Episode: 13005 | Step: 304989 | Reward: 17.73 | Max : 56.38
# Alpha: 0.1944 | Episode: 13006 | Step: 305007 | Reward: 13.92 | Max : 56.38
# Alpha: 0.1944 | Episode: 13007 | Step: 305026 | Reward: 14.81 | Max : 56.38
# Alpha: 0.1944 | Episode: 13008 | Step: 305046 | Reward: 15.59 | Max : 56.38
# Alpha: 0.1944 | Episode: 13009 | Step: 305067 | Reward: 16.64 | Max : 56.38
# Alpha: 0.1944 | Episode: 13010 | Step: 305094 | Reward: 21.61 | Max : 56.38
# Alpha: 0.1944 | Episode: 13011 | Step: 305114 | Reward: 15.88 | Max : 56.38
# Alpha: 0.1944 | Episode: 13012 | Step: 305135 | Reward: 15.45 | Max : 56.38
# Alpha: 0.1944 | Episode: 13013 | Step: 305165 | Reward: 23.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13014 | Step: 305181 | Reward: 12.47 | Max : 56.38
# Alpha: 0.1944 | Episode: 13015 | Step: 305198 | Reward: 13.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13016 | Step: 305216 | Reward: 14.33 | Max : 56.38
# Alpha: 0.1944 | Episode: 13017 | Step: 305251 | Reward: 25.15 | Max : 56.38
# Alpha: 0.1944 | Episode: 13018 | Step: 305271 | Reward: 15.41 | Max : 56.38
# Alpha: 0.1944 | Episode: 13019 | Step: 305292 | Reward: 16.75 | Max : 56.38
# Alpha: 0.1944 | Episode: 13020 | Step: 305311 | Reward: 15.22 | Max : 56.38
# Alpha: 0.1944 | Episode: 13021 | Step: 305345 | Reward: 27.18 | Max : 56.38
# Alpha: 0.1944 | Episode: 13022 | Step: 305373 | Reward: 22.18 | Max : 56.38
# Alpha: 0.1944 | Episode: 13023 | Step: 305395 | Reward: 17.10 | Max : 56.38
# Alpha: 0.1944 | Episode: 13024 | Step: 305413 | Reward: 14.19 | Max : 56.38
# Alpha: 0.1944 | Episode: 13025 | Step: 305441 | Reward: 21.94 | Max : 56.38
# Alpha: 0.1944 | Episode: 13026 | Step: 305468 | Reward: 19.06 | Max : 56.38
# Alpha: 0.1944 | Episode: 13027 | Step: 305486 | Reward: 14.15 | Max : 56.38
# Alpha: 0.1944 | Episode: 13028 | Step: 305507 | Reward: 16.50 | Max : 56.38
# Alpha: 0.1944 | Episode: 13029 | Step: 305525 | Reward: 14.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13030 | Step: 305543 | Reward: 14.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13031 | Step: 305561 | Reward: 14.01 | Max : 56.38
# Alpha: 0.1944 | Episode: 13032 | Step: 305581 | Reward: 15.93 | Max : 56.38
# Alpha: 0.1944 | Episode: 13033 | Step: 305617 | Reward: 28.49 | Max : 56.38
# Alpha: 0.1944 | Episode: 13034 | Step: 305634 | Reward: 13.23 | Max : 56.38
# Alpha: 0.1944 | Episode: 13035 | Step: 305661 | Reward: 20.61 | Max : 56.38
# Alpha: 0.1944 | Episode: 13036 | Step: 305681 | Reward: 15.86 | Max : 56.38
# Alpha: 0.1944 | Episode: 13037 | Step: 305699 | Reward: 14.14 | Max : 56.38
# Alpha: 0.1944 | Episode: 13038 | Step: 305718 | Reward: 15.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13039 | Step: 305745 | Reward: 21.06 | Max : 56.38
# Alpha: 0.1944 | Episode: 13040 | Step: 305779 | Reward: 26.79 | Max : 56.38
# Alpha: 0.1944 | Episode: 13041 | Step: 305805 | Reward: 20.82 | Max : 56.38
# Alpha: 0.1944 | Episode: 13042 | Step: 305826 | Reward: 16.75 | Max : 56.38
# Alpha: 0.1944 | Episode: 13043 | Step: 305843 | Reward: 13.20 | Max : 56.38
# Alpha: 0.1944 | Episode: 13044 | Step: 305861 | Reward: 14.11 | Max : 56.38
# Alpha: 0.1944 | Episode: 13045 | Step: 305882 | Reward: 16.35 | Max : 56.38
# Alpha: 0.1944 | Episode: 13046 | Step: 305908 | Reward: 20.68 | Max : 56.38
# Alpha: 0.1944 | Episode: 13047 | Step: 305949 | Reward: 31.92 | Max : 56.38
# Alpha: 0.1944 | Episode: 13048 | Step: 305985 | Reward: 26.16 | Max : 56.38
# Alpha: 0.1944 | Episode: 13049 | Step: 306019 | Reward: 26.43 | Max : 56.38
# Alpha: 0.1944 | Episode: 13050 | Step: 306045 | Reward: 20.44 | Max : 56.38
# Alpha: 0.1944 | Episode: 13051 | Step: 306064 | Reward: 15.10 | Max : 56.38
# Alpha: 0.1944 | Episode: 13052 | Step: 306088 | Reward: 18.71 | Max : 56.38
# Alpha: 0.1944 | Episode: 13053 | Step: 306106 | Reward: 14.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13054 | Step: 306122 | Reward: 12.16 | Max : 56.38
# Alpha: 0.1944 | Episode: 13055 | Step: 306141 | Reward: 15.06 | Max : 56.38
# Alpha: 0.1944 | Episode: 13056 | Step: 306170 | Reward: 22.72 | Max : 56.38
# Alpha: 0.1944 | Episode: 13057 | Step: 306191 | Reward: 16.69 | Max : 56.38
# Alpha: 0.1944 | Episode: 13058 | Step: 306210 | Reward: 15.04 | Max : 56.38
# Alpha: 0.1944 | Episode: 13059 | Step: 306230 | Reward: 15.88 | Max : 56.38
# Alpha: 0.1944 | Episode: 13060 | Step: 306247 | Reward: 13.04 | Max : 56.38
# Alpha: 0.1944 | Episode: 13061 | Step: 306270 | Reward: 18.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13062 | Step: 306293 | Reward: 18.65 | Max : 56.38
# Alpha: 0.1944 | Episode: 13063 | Step: 306311 | Reward: 14.27 | Max : 56.38
# Alpha: 0.1944 | Episode: 13064 | Step: 306351 | Reward: 28.74 | Max : 56.38
# Alpha: 0.1944 | Episode: 13065 | Step: 306371 | Reward: 15.92 | Max : 56.38
# Alpha: 0.1944 | Episode: 13066 | Step: 306401 | Reward: 21.90 | Max : 56.38
# Alpha: 0.1944 | Episode: 13067 | Step: 306424 | Reward: 17.80 | Max : 56.38
# Alpha: 0.1944 | Episode: 13068 | Step: 306442 | Reward: 14.10 | Max : 56.38
# Alpha: 0.1944 | Episode: 13069 | Step: 306464 | Reward: 17.67 | Max : 56.38
# Alpha: 0.1944 | Episode: 13070 | Step: 306483 | Reward: 13.70 | Max : 56.38
# Alpha: 0.1944 | Episode: 13071 | Step: 306500 | Reward: 13.46 | Max : 56.38
# Alpha: 0.1944 | Episode: 13072 | Step: 306527 | Reward: 20.89 | Max : 56.38
# Alpha: 0.1944 | Episode: 13073 | Step: 306556 | Reward: 21.79 | Max : 56.38
# Alpha: 0.1944 | Episode: 13074 | Step: 306577 | Reward: 15.97 | Max : 56.38
# Alpha: 0.1944 | Episode: 13075 | Step: 306594 | Reward: 13.19 | Max : 56.38
# Alpha: 0.1944 | Episode: 13076 | Step: 306614 | Reward: 15.44 | Max : 56.38
# Alpha: 0.1944 | Episode: 13077 | Step: 306639 | Reward: 20.44 | Max : 56.38
# Alpha: 0.1944 | Episode: 13078 | Step: 306659 | Reward: 16.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13079 | Step: 306686 | Reward: 21.58 | Max : 56.38
# Alpha: 0.1944 | Episode: 13080 | Step: 306704 | Reward: 14.03 | Max : 56.38
# Alpha: 0.1944 | Episode: 13081 | Step: 306726 | Reward: 17.62 | Max : 56.38
# Alpha: 0.1944 | Episode: 13082 | Step: 306751 | Reward: 19.80 | Max : 56.38
# Alpha: 0.1944 | Episode: 13083 | Step: 306771 | Reward: 15.64 | Max : 56.38
# Alpha: 0.1944 | Episode: 13084 | Step: 306789 | Reward: 14.20 | Max : 56.38
# Alpha: 0.1944 | Episode: 13085 | Step: 306807 | Reward: 14.03 | Max : 56.38
# Alpha: 0.1944 | Episode: 13086 | Step: 306835 | Reward: 22.22 | Max : 56.38
# Alpha: 0.1944 | Episode: 13087 | Step: 306861 | Reward: 19.97 | Max : 56.38
# Alpha: 0.1944 | Episode: 13088 | Step: 306883 | Reward: 17.27 | Max : 56.38
# Alpha: 0.1944 | Episode: 13089 | Step: 306903 | Reward: 16.05 | Max : 56.38
# Alpha: 0.1944 | Episode: 13090 | Step: 306932 | Reward: 22.21 | Max : 56.38
# Alpha: 0.1944 | Episode: 13091 | Step: 306949 | Reward: 13.27 | Max : 56.38
# Alpha: 0.1944 | Episode: 13092 | Step: 306971 | Reward: 17.65 | Max : 56.38
# Alpha: 0.1944 | Episode: 13093 | Step: 306997 | Reward: 20.30 | Max : 56.38
# Alpha: 0.1944 | Episode: 13094 | Step: 307036 | Reward: 30.74 | Max : 56.38
# Alpha: 0.1944 | Episode: 13095 | Step: 307054 | Reward: 14.32 | Max : 56.38
# Alpha: 0.1944 | Episode: 13096 | Step: 307071 | Reward: 13.24 | Max : 56.38
# Alpha: 0.1944 | Episode: 13097 | Step: 307097 | Reward: 20.63 | Max : 56.38
# Alpha: 0.1944 | Episode: 13098 | Step: 307124 | Reward: 21.33 | Max : 56.38
# Alpha: 0.1944 | Episode: 13099 | Step: 307156 | Reward: 26.13 | Max : 56.38
# Alpha: 0.1944 | Episode: 13100 | Step: 307185 | Reward: 22.71 | Max : 56.38
# Alpha: 0.1944 | Episode: 13101 | Step: 307208 | Reward: 18.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13102 | Step: 307238 | Reward: 22.23 | Max : 56.38
# Alpha: 0.1944 | Episode: 13103 | Step: 307261 | Reward: 18.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13104 | Step: 307288 | Reward: 21.32 | Max : 56.38
# Alpha: 0.1944 | Episode: 13105 | Step: 307316 | Reward: 22.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13106 | Step: 307335 | Reward: 14.98 | Max : 56.38
# Alpha: 0.1944 | Episode: 13107 | Step: 307375 | Reward: 29.17 | Max : 56.38
# Alpha: 0.1944 | Episode: 13108 | Step: 307394 | Reward: 15.19 | Max : 56.38
# Alpha: 0.1944 | Episode: 13109 | Step: 307411 | Reward: 13.35 | Max : 56.38
# Alpha: 0.1944 | Episode: 13110 | Step: 307428 | Reward: 13.13 | Max : 56.38
# Alpha: 0.1944 | Episode: 13111 | Step: 307445 | Reward: 13.28 | Max : 56.38
# Alpha: 0.1944 | Episode: 13112 | Step: 307477 | Reward: 23.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13113 | Step: 307506 | Reward: 23.65 | Max : 56.38
# Alpha: 0.1944 | Episode: 13114 | Step: 307525 | Reward: 15.22 | Max : 56.38
# Alpha: 0.1944 | Episode: 13115 | Step: 307556 | Reward: 22.33 | Max : 56.38
# Alpha: 0.1944 | Episode: 13116 | Step: 307574 | Reward: 14.45 | Max : 56.38
# Alpha: 0.1944 | Episode: 13117 | Step: 307605 | Reward: 24.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13118 | Step: 307626 | Reward: 16.28 | Max : 56.38
# Alpha: 0.1944 | Episode: 13119 | Step: 307656 | Reward: 23.68 | Max : 56.38
# Alpha: 0.1944 | Episode: 13120 | Step: 307676 | Reward: 15.93 | Max : 56.38
# Alpha: 0.1944 | Episode: 13121 | Step: 307693 | Reward: 13.40 | Max : 56.38
# Alpha: 0.1944 | Episode: 13122 | Step: 307733 | Reward: 30.80 | Max : 56.38
# Alpha: 0.1944 | Episode: 13123 | Step: 307754 | Reward: 16.49 | Max : 56.38
# Alpha: 0.1944 | Episode: 13124 | Step: 307774 | Reward: 14.56 | Max : 56.38
# Alpha: 0.1944 | Episode: 13125 | Step: 307799 | Reward: 18.26 | Max : 56.38
# Alpha: 0.1944 | Episode: 13126 | Step: 307825 | Reward: 19.72 | Max : 56.38
# Alpha: 0.1944 | Episode: 13127 | Step: 307856 | Reward: 24.43 | Max : 56.38
# Alpha: 0.1944 | Episode: 13128 | Step: 307908 | Reward: 39.49 | Max : 56.38
# Alpha: 0.1944 | Episode: 13129 | Step: 307927 | Reward: 15.31 | Max : 56.38
# Alpha: 0.1944 | Episode: 13130 | Step: 307948 | Reward: 16.66 | Max : 56.38
# Alpha: 0.1944 | Episode: 13131 | Step: 307974 | Reward: 20.56 | Max : 56.38
# Alpha: 0.1944 | Episode: 13132 | Step: 308001 | Reward: 21.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13133 | Step: 308022 | Reward: 17.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13134 | Step: 308043 | Reward: 16.52 | Max : 56.38
# Alpha: 0.1944 | Episode: 13135 | Step: 308064 | Reward: 16.70 | Max : 56.38
# Alpha: 0.1944 | Episode: 13136 | Step: 308083 | Reward: 14.80 | Max : 56.38
# Alpha: 0.1944 | Episode: 13137 | Step: 308108 | Reward: 19.82 | Max : 56.38
# Alpha: 0.1944 | Episode: 13138 | Step: 308128 | Reward: 15.62 | Max : 56.38
# Alpha: 0.1944 | Episode: 13139 | Step: 308158 | Reward: 23.47 | Max : 56.38
# Alpha: 0.1944 | Episode: 13140 | Step: 308175 | Reward: 13.38 | Max : 56.38
# Alpha: 0.1944 | Episode: 13141 | Step: 308196 | Reward: 16.59 | Max : 56.38
# Alpha: 0.1944 | Episode: 13142 | Step: 308215 | Reward: 14.78 | Max : 56.38
# Alpha: 0.1944 | Episode: 13143 | Step: 308246 | Reward: 24.29 | Max : 56.38
# Alpha: 0.1944 | Episode: 13144 | Step: 308266 | Reward: 15.85 | Max : 56.38
# Alpha: 0.1944 | Episode: 13145 | Step: 308285 | Reward: 14.95 | Max : 56.38
# Alpha: 0.1944 | Episode: 13146 | Step: 308305 | Reward: 15.94 | Max : 56.38
# Alpha: 0.1944 | Episode: 13147 | Step: 308326 | Reward: 16.91 | Max : 56.38
# Alpha: 0.1944 | Episode: 13148 | Step: 308345 | Reward: 14.99 | Max : 56.38
# Alpha: 0.1944 | Episode: 13149 | Step: 308382 | Reward: 26.00 | Max : 56.38
# Alpha: 0.1944 | Episode: 13150 | Step: 308400 | Reward: 14.26 | Max : 56.38
# Alpha: 0.1944 | Episode: 13151 | Step: 308419 | Reward: 15.36 | Max : 56.38
# Alpha: 0.1944 | Episode: 13152 | Step: 308449 | Reward: 23.63 | Max : 56.38
# Alpha: 0.1944 | Episode: 13153 | Step: 308466 | Reward: 12.90 | Max : 56.38
# Alpha: 0.1944 | Episode: 13154 | Step: 308492 | Reward: 18.91 | Max : 56.38
# Alpha: 0.1944 | Episode: 13155 | Step: 308529 | Reward: 30.55 | Max : 56.38
# Alpha: 0.1944 | Episode: 13156 | Step: 308546 | Reward: 13.52 | Max : 56.38
# Alpha: 0.1944 | Episode: 13157 | Step: 308569 | Reward: 18.02 | Max : 56.38
# Alpha: 0.1944 | Episode: 13158 | Step: 308600 | Reward: 24.58 | Max : 56.38

# %%
def evaluate_model(actor_model, critic_model, env, num_episodes=10, max_timesteps=1000, render=False):
    """
    Function to evaluate the Actor-Critic model's performance.

    Args:
        actor_model (nn.Module): The Actor model.
        critic_model (nn.Module): The Critic model.
        env (gym.Env): The environment to evaluate on.
        num_episodes (int): The number of episodes to run during evaluation.
        max_timesteps (int): Maximum timesteps per episode.
        render (bool): Whether to render the environment during evaluation.

    Returns:
        average_reward (float): Average reward across all episodes.
    """
    actor_model.eval()  # Set actor model to evaluation mode
    critic_model.eval()  # Set critic model to evaluation mode
    total_rewards = []

    with torch.no_grad():  # No gradients needed for evaluation
        for episode in range(num_episodes):
            state , _ = env.reset()  # Reset environment at the start of each episode
            episode_reward = 0

            for t in range(max_timesteps):
                if render:
                    env.render()  # Render environment if required

                # Get the action from the actor model
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                action_probs , log_prob  = actor_model(state_tensor)  # Actor generates action probabilities
                action = action_probs.detach().cpu().numpy()[0]  # Assuming discrete actions

                # Use the critic to evaluate the state
                #state_value = critic_model(state_tensor , action)  # Critic gives value estimate

                # Apply the action to the environment
                next_state, reward, done, _ , info= env.step(action)

                episode_reward += reward
                state = next_state

                if done:
                    break

            total_rewards.append(episode_reward)
            
            print(total_rewards)

    average_reward = sum(total_rewards) / num_episodes
    print(f"Average reward over {num_episodes} episodes: {average_reward}")
    

    
    return average_reward
